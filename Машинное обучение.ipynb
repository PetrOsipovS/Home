# %% [markdown]
# # Подготовка базовой модели
# Обучите простую модель классификации с помощью DecisionTreeClassifier на данных из датасета vehicles_dataset_prepared.csv. Для этого сделайте следующие шаги:
#
# # Обучите модель дерева решений с зафиксированным random_state на тренировочной выборке.
# # Сделайте предикт на тестовой выборке.
# # Замерьте точность на тестовой выборке и выведите матрицу ошибок.
# # Удалите фичи с нулевыми весами по feature_importance из тренировочной и тестовой выборок.
# # Заново обучите модель и измерьте качество.

# %%
import pandas as pd
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import train_test_split 
from sklearn.metrics import accuracy_score, confusion_matrix

# %%
df = pd.read_csv('vehicles_dataset_prepared.csv')

df_prepared = df.copy()
df_prepared = df_prepared.drop(['price', 'odometer/price_std'], axis=1)

x = df_prepared.drop(['price_category'], axis=1)
y = df_prepared['price_category']

x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.3, random_state=42)

# %%
x_train.shape, x_test.shape
# Out:
# ((6733, 1460), (2886, 1460))

# %%
clf = DecisionTreeClassifier()
clf.fit(x_train, y_train)
# Out:
# DecisionTreeClassifier()

# %%
predicted_test = clf.predict(x_test)

# %%
print(accuracy_score(y_test, predicted_test))
confusion_matrix(y_test, predicted_test)
# Out:
# 0.6722106722106722
# array([[740,  50, 207],
#        [ 46, 688, 219],
#        [196, 228, 512]], dtype=int64)

# %%
clf.feature_importances_
# Out:
# array([0.03158202, 0.00041354, 0.00179785, ..., 0.00273258, 0.01544665,
#        0.02331827])

# %%
f_imp_list = list(zip(x_train.columns, clf.feature_importances_))
f_imp_list
# Out:
# [('id', 0.03158202261840626),
#  ('is_audi', 0.0004135369574176561),
#  ('is_ford', 0.001797849737979432),
#  ('is_chevrolet', 0.0036328771792079216),
#  ('is_toyota', 0.0024952016341785142),
#  ('x0_diesel', 0.033097961449185156),
#  ('x0_electric', 0.0006947852275420483),
#  ('x0_gas', 0.002624342857727372),
#  ('x0_hybrid', 0.0013858022386644174),
#  ('x0_other', 0.000798036576408809),
#  ('std_scaled_odometer', 0.07976968187721656),
#  ('short_model_-benz', 0.0),
#  ('short_model_1', 0.0),
#  ('short_model_124', 0.0),
#  ('short_model_128i', 0.0),
#  ('short_model_135i', 0.0),
#  ('short_model_1500', 0.00103455870450748),
#  ('short_model_163869', 0.0),
#  ('short_model_1928', 0.0),
#  ('short_model_1951', 0.0),
#  ('short_model_1954', 0.0),
#  ('short_model_1960s', 0.0),
#  ('short_model_1966', 0.00038346458824074065),
#  ('short_model_1968', 0.0),
#  ('short_model_1972', 0.0),
#  ('short_model_1977', 0.0),
#  ('short_model_1978', 0.0),
#  ('short_model_198.5', 0.0),
#  ('short_model_1988', 0.0),
#  ('short_model_1994', 0.0),
#  ('short_model_1999', 0.0),
#  ('short_model_2', 0.0),
#  ('short_model_200', 0.0),
#  ('short_model_2000', 0.0),
#  ('short_model_2002', 0.0003899142984405082),
#  ('short_model_2006', 0.0),
#  ('short_model_2007', 0.0),
#  ('short_model_2008', 0.0),
#  ('short_model_2009', 0.0),
#  ('short_model_2012', 0.0),
#  ('short_model_2015', 0.0),
#  ('short_model_2016', 0.0),
#  ('short_model_2017', 0.0),
#  ('short_model_2018', 0.0),
#  ('short_model_210', 0.0),
#  ('short_model_240', 0.0),
#  ('short_model_2500', 0.0004047702972470453),
#  ('short_model_2500hd', 0.0),
#  ('short_model_280zx', 0.0),
#  ('short_model_3', 0.0003342122558061499),
#  ('short_model_3-series', 0.00041995225357931094),
#  ('short_model_3-window', 0.0),
#  ('short_model_3.2', 0.0),
#  ('short_model_300', 0.0),
#  ('short_model_300-series', 0.0),
#  ('short_model_300c', 0.0),
#  ('short_model_300s', 0.0),
#  ('short_model_300zx', 0.0),
#  ('short_model_3100', 0.0),
#  ('short_model_318i', 0.0),
#  ('short_model_320i', 0.0),
#  ('short_model_323i', 0.0),
#  ('short_model_325ci', 0.0),
#  ('short_model_325i', 0.0),
#  ('short_model_325is', 0.00042211523055373445),
#  ('short_model_325xi', 0.0),
#  ('short_model_328', 0.0),
#  ('short_model_328ci', 0.0),
#  ('short_model_328d', 0.0),
#  ('short_model_328i', 0.0003896887840978581),
#  ('short_model_328xi', 0.000844576270370527),
#  ('short_model_330i', 0.0),
#  ('short_model_330xi', 0.00042006119924662517),
#  ('short_model_335i', 0.0),
#  ('short_model_335xi', 0.0),
#  ('short_model_350', 0.0),
#  ('short_model_3500', 0.0),
#  ('short_model_3500hd', 0.0),
#  ('short_model_350z', 0.0),
#  ('short_model_370z', 0.0),
#  ('short_model_380sl', 0.0),
#  ('short_model_3i', 0.0),
#  ('short_model_4', 0.0),
#  ('short_model_4-runner', 0.0),
#  ('short_model_428', 0.0003876173069916691),
#  ('short_model_430i', 0.0),
#  ('short_model_435i', 0.0),
#  ('short_model_440xi', 0.0),
#  ('short_model_4500', 0.0),
#  ('short_model_4runner', 0.0021040569753639133),
#  ('short_model_4x4', 0.0),
#  ('short_model_5', 0.0),
#  ('short_model_5-series', 0.0),
#  ('short_model_50', 0.0),
#  ('short_model_500', 0.0),
#  ('short_model_500c', 0.0),
#  ('short_model_500l', 0.0),
#  ('short_model_500x', 0.0),
#  ('short_model_525i', 0.0),
#  ('short_model_528i', 0.0),
#  ('short_model_528xi', 0.0),
#  ('short_model_530', 0.0),
#  ('short_model_530i', 0.0),
#  ('short_model_535i', 0.0),
#  ('short_model_535xi', 0.0),
#  ('short_model_540i', 0.0),
#  ('short_model_545i', 0.0),
#  ('short_model_5500', 0.0),
#  ('short_model_5500hd', 0.0),
#  ('short_model_550i', 0.0),
#  ('short_model_5th', 0.0),
#  ('short_model_6', 0.0),
#  ('short_model_640', 0.0),
#  ('short_model_645ci', 0.0),
#  ('short_model_650i', 0.0),
#  ('short_model_650xi', 0.0),
#  ('short_model_7', 0.0),
#  ('short_model_750', 0.0),
#  ('short_model_750i', 0.0),
#  ('short_model_750xi', 0.0),
#  ('short_model_86', 0.0),
#  ('short_model_911', 0.0),
#  ('short_model_914', 0.0),
#  ('short_model_928', 0.0),
#  ('short_model_944', 0.0),
#  ('short_model_ACURA*', 0.0),
#  ('short_model_ALL', 0.0),
#  ('short_model_AM', 0.00041590858500320884),
#  ('short_model_AMC', 0.0),
#  ('short_model_ASC', 0.0),
#  ('short_model_Acuarea', 0.0),
#  ('short_model_American', 0.0),
#  ('short_model_BUY', 0.0),
#  ('short_model_Bentley', 0.0),
#  ('short_model_Blue', 0.0),
#  ('short_model_Buicks', 0.0),
#  ('short_model_C', 0.0),
#  ('short_model_CHEVORLET', 0.0),
#  ('short_model_CLICK', 0.0004138231241984923),
#  ('short_model_Champion', 0.0),
#  ('short_model_Chevey', 0.0),
#  ('short_model_Chevorlet', 0.000406070302148309),
#  ('short_model_Comanche', 0.0),
#  ('short_model_Comet', 0.0),
#  ('short_model_D7FH173552', 0.0),
#  ('short_model_DODGE1500', 0.0),
#  ('short_model_Diahatsu', 0.0),
#  ('short_model_E46', 0.0),
#  ('short_model_EASY', 0.0),
#  ('short_model_Eagle', 0.0),
#  ('short_model_Emergency', 0.0),
#  ('short_model_F-250', 0.0),
#  ('short_model_F250', 0.0004190989217499753),
#  ('short_model_FORD*', 0.0),
#  ('short_model_FORD/RANGER', 0.0),
#  ('short_model_FREIGHTLINER', 0.0),
#  ('short_model_FRRV', 0.0),
#  ('short_model_Flexible', 0.0007427980664340525),
#  ('short_model_FordE350', 0.0),
#  ('short_model_Freightliner', 0.0),
#  ('short_model_Frtlner', 0.0),
#  ('short_model_GCM', 0.0),
#  ('short_model_GEHL', 0.0),
#  ('short_model_GMC,', 0.0),
#  ('short_model_GMX', 0.0),
#  ('short_model_GRAND', 0.0),
#  ('short_model_GULF', 0.0),
#  ('short_model_Genesis', 0.0),
#  ('short_model_Gx', 0.0),
#  ('short_model_HINO', 0.0),
#  ('short_model_HUMMER', 0.0003914403818003544),
#  ('short_model_Hino', 0.0),
#  ('short_model_Hobda', 0.0),
#  ('short_model_Hot', 0.0),
#  ('short_model_Hummer', 0.0),
#  ('short_model_IC', 0.0),
#  ('short_model_INTERNATIONAL', 0.0),
#  ('short_model_International', 0.0),
#  ('short_model_Isizu', 0.0),
#  ('short_model_Isuzu', 0.0),
#  ('short_model_JM1BK32F871604924', 0.0),
#  ('short_model_Janesville', 0.0),
#  ('short_model_Jauguar', 0.0),
#  ('short_model_Jayco', 0.0),
#  ('short_model_Kaiser', 0.0),
#  ('short_model_Lotus', 0.0),
#  ('short_model_MASERATI', 0.0),
#  ('short_model_MERCUTY', 0.0),
#  ('short_model_MERDECES', 0.0),
#  ('short_model_MGB', 0.0),
#  ('short_model_MITUSBISHI', 0.0),
#  ('short_model_MV-1', 0.0),
#  ('short_model_Maserati', 0.0),
#  ('short_model_Minin', 0.0),
#  ('short_model_Nascar', 0.0),
#  ('short_model_OLDSMOBILE', 0.0),
#  ('short_model_PLYMOUTH', 0.0),
#  ('short_model_PROGRAMS', 0.0006581410575874951),
#  ('short_model_Peterbilt', 0.0),
#  ('short_model_Pierce', 0.0),
#  ('short_model_Plymouth', 0.00040510576461351503),
#  ('short_model_QX', 0.0),
#  ('short_model_S60', 0.0),
#  ('short_model_SCION', 0.0),
#  ('short_model_SL', 0.0),
#  ('short_model_Saab', 0.0),
#  ('short_model_Scion', 0.004865746378858322),
#  ('short_model_Sea', 0.0),
#  ('short_model_Sterling', 0.0),
#  ('short_model_Studebaker', 0.0),
#  ('short_model_Suzuki', 0.0),
#  ('short_model_THOMAS', 0.0),
#  ('short_model_Thomas', 0.0),
#  ('short_model_Town', 0.0),
#  ('short_model_Triumph', 0.0),
#  ('short_model_Voltswagon', 0.0),
#  ('short_model_Xx', 0.0),
#  ('short_model_a-class', 0.0),
#  ('short_model_a3', 0.0),
#  ('short_model_a3,', 0.0),
#  ('short_model_a4', 0.0007870877769526716),
#  ('short_model_a5', 0.0),
#  ('short_model_a6', 0.0),
#  ('short_model_a7', 0.0),
#  ('short_model_a8', 0.0),
#  ('short_model_acadia', 0.0),
#  ('short_model_accent', 0.0),
#  ('short_model_accord', 0.0),
#  ('short_model_all', 0.0),
#  ('short_model_allante', 0.0),
#  ('short_model_allroad', 0.0),
#  ('short_model_altima', 0.0010981537775514947),
#  ('short_model_am', 0.0),
#  ('short_model_amc', 0.0),
#  ('short_model_arcadia', 0.0),
#  ('short_model_armada', 0.0),
#  ('short_model_arteon', 0.0),
#  ('short_model_ascent', 0.0),
#  ('short_model_aspen', 0.0),
#  ('short_model_astra', 0.0),
#  ('short_model_astro', 0.0),
#  ('short_model_atlas', 0.0),
#  ('short_model_ats', 0.0),
#  ('short_model_aura', 0.0),
#  ('short_model_autobiography', 0.0),
#  ('short_model_avalanche', 0.001091507141819505),
#  ('short_model_avalon', 0.0),
#  ('short_model_avanger', 0.0),
#  ('short_model_avenger', 0.0),
#  ('short_model_aveo', 0.0),
#  ('short_model_aviator', 0.0),
#  ('short_model_azera', 0.0),
#  ('short_model_aztek', 0.0),
#  ('short_model_b-class', 0.0),
#  ('short_model_b-series', 0.0),
#  ('short_model_b2200', 0.0),
#  ('short_model_b2300', 0.0),
#  ('short_model_b2600i', 0.0),
#  ('short_model_baja', 0.0),
#  ('short_model_beetle', 0.0),
#  ('short_model_bel', 0.0),
#  ('short_model_belair', 0.0),
#  ('short_model_benz', 0.0),
#  ('short_model_blackwood', 0.0),
#  ('short_model_blazer', 0.0),
#  ('short_model_blue', 0.0),
#  ('short_model_bolt', 0.0),
#  ('short_model_bonanza', 0.0),
#  ('short_model_bonneville', 0.0),
#  ('short_model_boxster', 0.0),
#  ('short_model_bronco', 0.0),
#  ('short_model_brz', 0.0),
#  ('short_model_bug', 0.0),
#  ('short_model_bus', 0.0),
#  ('short_model_c', 0.0),
#  ('short_model_c-10', 0.0),
#  ('short_model_c-7500', 0.0),
#  ('short_model_c-class', 0.0),
#  ('short_model_c-hr', 0.00040097322017564833),
#  ('short_model_c-max', 0.0),
#  ('short_model_c/k', 0.0),
#  ('short_model_c10', 0.0),
#  ('short_model_c250', 0.0),
#  ('short_model_c280', 0.0),
#  ('short_model_c30', 0.0),
#  ('short_model_c300', 0.0),
#  ('short_model_c4500', 0.0),
#  ('short_model_c5500', 0.0),
#  ('short_model_c60', 0.0),
#  ('short_model_c6500', 0.0),
#  ('short_model_c70', 0.0),
#  ('short_model_c8500', 0.0),
#  ('short_model_cabellero', 0.0),
#  ('short_model_cabrio', 0.0),
#  ('short_model_caddilac', 0.0),
#  ('short_model_cadenza', 0.0),
#  ('short_model_caliber', 0.0),
#  ('short_model_camaro', 0.000425361052844191),
#  ('short_model_camary', 0.0),
#  ('short_model_camero', 0.0),
#  ('short_model_camry', 0.0006439800108542663),
#  ('short_model_canyon', 0.0004037805455301814),
#  ('short_model_capri', 0.0),
#  ('short_model_caprice', 0.0),
#  ('short_model_captiva', 0.0),
#  ('short_model_caravan', 0.0),
#  ('short_model_caravan/grand', 0.0),
#  ('short_model_cargo', 0.0),
#  ('short_model_cascada', 0.0),
#  ('short_model_cavalier', 0.0),
#  ('short_model_cayenne', 0.0004127855506578767),
#  ('short_model_cayman', 0.0),
#  ('short_model_cc', 0.0004113381609921843),
#  ('short_model_cc300', 0.0),
#  ('short_model_cc4500', 0.0),
#  ('short_model_century', 0.0),
#  ('short_model_certified', 0.0),
#  ('short_model_challenger', 0.00035649307285989313),
#  ('short_model_charger', 0.0),
#  ('short_model_cherokee', 0.0004031249338713303),
#  ('short_model_chevelle', 0.0),
#  ('short_model_chevorlet', 0.0),
#  ('short_model_chryler', 0.0),
#  ('short_model_chysler', 0.0),
#  ('short_model_city', 0.0),
#  ('short_model_civic', 0.0004581553290271888),
#  ('short_model_cj-5', 0.0),
#  ('short_model_cj2a', 0.0),
#  ('short_model_cj5', 0.0),
#  ('short_model_cj7', 0.0),
#  ('short_model_cj8', 0.0),
#  ('short_model_cl-class', 0.0),
#  ('short_model_cla', 0.0),
#  ('short_model_cla-class', 0.0),
#  ('short_model_clarity', 0.0),
#  ('short_model_classic', 0.0),
#  ('short_model_classuc', 0.0),
#  ('short_model_clk', 0.0),
#  ('short_model_clk-class', 0.0),
#  ('short_model_clk350', 0.0),
#  ('short_model_cls-class', 0.0),
#  ('short_model_cls550', 0.0),
#  ('short_model_clubman', 0.0),
#  ('short_model_cmax', 0.0),
#  ('short_model_cobalt', 0.0),
#  ('short_model_colbalt', 0.0),
#  ('short_model_colorado', 0.0015455319755306191),
#  ('short_model_comet', 0.0),
#  ('short_model_commander', 0.0),
#  ('short_model_compass', 0.0),
#  ('short_model_concorde', 0.0),
#  ('short_model_conquest', 0.0),
#  ('short_model_continental', 0.0),
#  ('short_model_convertible', 0.0),
#  ('short_model_cooper', 0.0006903211360097658),
#  ('short_model_corolla', 0.0025530887672715486),
#  ('short_model_corsair', 0.0),
#  ('short_model_corvette', 0.0009957858969400686),
#  ('short_model_cougar', 0.0),
#  ('short_model_country', 0.0),
#  ('short_model_countryman', 0.0),
#  ('short_model_coupe', 0.0),
#  ('short_model_cr-v', 0.0),
#  ('short_model_crew', 0.0),
#  ('short_model_crossfire', 0.0),
#  ('short_model_crosstour', 0.0),
#  ('short_model_crosstrek', 0.0),
#  ('short_model_crown', 0.0),
#  ('short_model_cruze', 0.0021785661028214665),
#  ('short_model_crv', 0.0),
#  ('short_model_crz', 0.0),
#  ('short_model_ct', 0.0),
#  ('short_model_ct4', 0.0),
#  ('short_model_ct5', 0.0),
#  ('short_model_ct6', 0.0),
#  ('short_model_cts', 0.0),
#  ('short_model_cts-v', 0.0),
#  ('short_model_cts4', 0.0),
#  ('short_model_cube', 0.0),
#  ('short_model_cvr', 0.0),
#  ('short_model_cx-3', 0.0),
#  ('short_model_cx-5', 0.0),
#  ('short_model_cx-7', 0.0),
#  ('short_model_cx-9', 0.0),
#  ('short_model_cx7', 0.0),
#  ('short_model_cx9', 0.0),
#  ('short_model_d50', 0.0),
#  ('short_model_dakota', 0.0),
#  ('short_model_dart', 0.00039668678441625086),
#  ('short_model_davidson', 0.0004218548426910259),
#  ('short_model_dealer*', 0.0),
#  ('short_model_defender', 0.0),
#  ('short_model_deisel', 0.0),
#  ('short_model_deluxe', 0.0),
#  ('short_model_denali', 0.0),
#  ('short_model_deville', 0.0),
#  ('short_model_diesel', 0.0),
#  ('short_model_discovery', 0.0),
#  ('short_model_dts', 0.0),
#  ('short_model_dump', 0.0),
#  ('short_model_duramax', 0.0),
#  ('short_model_durango', 0.0004084816459852943),
#  ('short_model_durangon', 0.0),
#  ('short_model_e', 0.0),
#  ('short_model_e-150', 0.0003342122558061499),
#  ('short_model_e-250', 0.0),
#  ('short_model_e-350', 0.0007127535996839997),
#  ('short_model_e-450', 0.0),
#  ('short_model_e-class', 0.0),
#  ('short_model_e-golf', 0.0004298292450102766),
#  ('short_model_e-pace', 0.0),
#  ('short_model_e-series', 0.0006918532295582757),
#  ('short_model_e150', 0.0),
#  ('short_model_e250', 0.0),
#  ('short_model_e320', 0.0),
#  ('short_model_e350', 0.0003977238373472234),
#  ('short_model_e450', 0.0),
#  ('short_model_e46', 0.0),
#  ('short_model_e500', 0.0),
#  ('short_model_echo', 0.0),
#  ('short_model_eclipse', 0.0),
#  ('short_model_econoline', 0.0),
#  ('short_model_ecosport', 0.00043074034259520485),
#  ('short_model_edge', 0.000436332667302474),
#  ('short_model_el', 0.0),
#  ('short_model_elantra', 0.0013864423281385954),
#  ('short_model_elcamino', 0.0),
#  ('short_model_eldorado', 0.0),
#  ('short_model_element', 0.0),
#  ('short_model_enclave', 0.0),
#  ('short_model_encore', 0.0006314375788163085),
#  ('short_model_endeavor', 0.0),
#  ('short_model_envision', 0.0),
#  ('short_model_envoy', 0.0),
#  ('short_model_eos', 0.0),
#  ('short_model_eqinox', 0.0),
#  ('short_model_equinox', 0.0002970775607165777),
#  ('short_model_es', 0.0006230376620583781),
#  ('short_model_es300', 0.0),
#  ('short_model_es330', 0.0),
#  ('short_model_es350', 0.0),
#  ('short_model_escalade', 0.0017808276175028724),
#  ('short_model_escape', 0.0022896528159364357),
#  ('short_model_escape-se,', 0.0),
#  ('short_model_escort', 0.0),
#  ('short_model_eurovan', 0.00043253345502062895),
#  ('short_model_evoque', 0.0),
#  ('short_model_excursion', 0.0003988943753081226),
#  ('short_model_expedition', 0.0),
#  ('short_model_explorer', 0.00037251104792047424),
#  ('short_model_express', 0.0013236306142098788),
#  ('short_model_f', 0.0),
#  ('short_model_f-100', 0.0),
#  ('short_model_f-150', 0.006112665483013556),
#  ('short_model_f-250', 0.003001630284946771),
#  ('short_model_f-250sd', 0.0006139008617778531),
#  ('short_model_f-350', 0.0011081106692366364),
#  ('short_model_f-350sd', 0.0),
#  ('short_model_f-450', 0.0),
#  ('short_model_f-450sd', 0.0),
#  ('short_model_f-550', 0.0),
#  ('short_model_f-650', 0.0),
#  ('short_model_f-750', 0.0),
#  ('short_model_f-pace', 0.0),
#  ('short_model_f-type', 0.0),
#  ('short_model_f1', 0.0),
#  ('short_model_f100', 0.0),
#  ('short_model_f150', 0.0028381501048308114),
#  ('short_model_f250', 0.0016949566264939943),
#  ('short_model_f350', 0.0),
#  ('short_model_f450', 0.0),
#  ('short_model_f450sd', 0.0),
#  ('short_model_f50', 0.0),
#  ('short_model_f550', 0.0),
#  ('short_model_f600', 0.0),
#  ('short_model_f650', 0.0008395216748567141),
#  ('short_model_f700', 0.0),
#  ('short_model_f750', 0.0),
#  ('short_model_falcon', 0.0),
#  ('short_model_fe', 0.0),
#  ('short_model_fiero', 0.0),
#  ('short_model_fiesta', 0.0002864676478338427),
#  ('short_model_firebird', 0.0),
#  ('short_model_fit', 0.0008582988981001105),
#  ('short_model_five', 0.0),
#  ('short_model_fj', 0.0019827623767689996),
#  ('short_model_fj40', 0.0),
#  ('short_model_fleetmaster', 0.0),
#  ('short_model_fleetwood', 0.0),
#  ('short_model_flex', 0.0),
#  ('short_model_focus', 0.0024570664292030927),
#  ('short_model_fords', 0.0),
#  ('short_model_forester', 0.0),
#  ('short_model_forte', 0.00040470065884890075),
#  ('short_model_forte5', 0.0),
#  ('short_model_foxbody', 0.0),
#  ('short_model_freestar', 0.0),
#  ('short_model_freestyle', 0.0003899142984405082),
#  ('short_model_freightliner', 0.0),
#  ('short_model_frontier', 0.00040584065035431216),
#  ('short_model_fusion', 0.0011751522216655397),
#  ('short_model_fuso', 0.0),
#  ('short_model_fx35', 0.0),
#  ('short_model_fx45', 0.0),
#  ('short_model_g', 0.0012690028497089891),
#  ('short_model_g-class', 0.0),
#  ('short_model_g.', 0.0),
#  ('short_model_g20', 0.0),
#  ('short_model_g30', 0.0),
#  ('short_model_g35', 0.0),
#  ('short_model_g35x', 0.0),
#  ('short_model_g37', 0.0004329252529728255),
#  ('short_model_g37s', 0.0),
#  ('short_model_g37x', 0.0),
#  ('short_model_g4500', 0.0),
#  ('short_model_g5', 0.0),
#  ('short_model_g6', 0.0004084816459852943),
#  ('short_model_g8', 0.0),
#  ('short_model_galant', 0.0),
#  ('short_model_genesis', 0.0003994320144088439),
#  ('short_model_ghia', 0.0),
#  ('short_model_gl', 0.0),
#  ('short_model_gl-class', 0.0),
#  ('short_model_gl450', 0.0),
#  ('short_model_gla', 0.0),
#  ('short_model_gla-class', 0.0004510634355021308),
#  ('short_model_gladiator', 0.0),
#  ('short_model_glc', 0.0),
#  ('short_model_glc-class', 0.0),
#  ('short_model_gle', 0.0),
#  ('short_model_gle-class', 0.0),
#  ('short_model_glk', 0.0),
#  ('short_model_glk-class', 0.0),
#  ('short_model_glk350', 0.0),
#  ('short_model_gls', 0.0),
#  ('short_model_gmc/chev', 0.0),
#  ('short_model_gmce', 0.0),
#  ('short_model_gmt-400', 0.0),
#  ('short_model_golf', 0.001109068313848265),
#  ('short_model_gr', 0.0),
#  ('short_model_grand', 0.0014989074046955855),
#  ('short_model_grandville', 0.0),
#  ('short_model_grumman', 0.0),
#  ('short_model_gs', 0.0),
#  ('short_model_gs350', 0.0),
#  ('short_model_gs430', 0.0),
#  ('short_model_gt', 0.0),
#  ('short_model_gt-r', 0.0),
#  ('short_model_gti', 0.0),
#  ('short_model_gto', 0.0008485131539757174),
#  ('short_model_gx', 0.0007628859770442962),
#  ('short_model_gx460', 0.0),
#  ('short_model_gx470', 0.0),
#  ('short_model_hardbody', 0.0),
#  ('short_model_hardtop', 0.0),
#  ('short_model_hearse', 0.0),
#  ('short_model_hhr', 0.0),
#  ('short_model_hiace', 0.0),
#  ('short_model_high', 0.0),
#  ('short_model_highlander', 0.0003661803846223917),
#  ('short_model_hr-v', 0.0),
#  ('short_model_hse', 0.0),
#  ('short_model_hummer', 0.0009227401667930807),
#  ('short_model_hyndai', 0.0),
#  ('short_model_i-miev', 0.0),
#  ('short_model_i3', 0.0004131608979428074),
#  ('short_model_i30', 0.0),
#  ('short_model_i35', 0.0),
#  ('short_model_ilx', 0.0003364770226184638),
#  ('short_model_impala', 0.0007352650261531871),
#  ('short_model_impreza', 0.001114006524469102),
#  ('short_model_insight', 0.0),
#  ('short_model_international', 0.0),
#  ('short_model_ion', 0.0),
#  ('short_model_ioniq', 0.0),
#  ('short_model_is', 0.0004377985105296935),
#  ('short_model_is250', 0.0),
#  ('short_model_is300', 0.0),
#  ('short_model_isf', 0.00037181258970562375),
#  ('short_model_isuzu', 0.0),
#  ('short_model_jeepster', 0.0),
#  ('short_model_jetta', 0.0025695856050929216),
#  ('short_model_jimmy', 0.0),
#  ('short_model_jouney', 0.0),
#  ('short_model_journey', 0.0),
#  ('short_model_juke', 0.0),
#  ('short_model_jx35', 0.0),
#  ('short_model_k10', 0.0),
#  ('short_model_k20', 0.0),
#  ('short_model_k30', 0.0),
#  ('short_model_k5', 0.0),
#  ('short_model_k900', 0.00042216284943934743),
#  ('short_model_kicks', 0.0),
#  ('short_model_kodiak', 0.0),
#  ('short_model_l', 0.0),
#  ('short_model_l300', 0.0),
#  ('short_model_lacrosse', 0.0),
#  ('short_model_lancer', 0.0),
#  ('short_model_land', 0.0009270182405919849),
#  ('short_model_landcruiser', 0.0),
#  ('short_model_leaf', 0.00022193952269908052),
#  ('short_model_legacy', 0.0),
#  ('short_model_legend', 0.0),
#  ('short_model_lemans', 0.0),
#  ('short_model_lesabre', 0.0),
#  ('short_model_liberty', 0.0),
#  ('short_model_lifted', 0.0),
#  ('short_model_lightning', 0.0),
#  ('short_model_limousine', 0.0),
#  ('short_model_long', 0.0),
#  ('short_model_lr2', 0.0),
#  ('short_model_lr3', 0.0),
#  ('short_model_lr4', 0.0),
#  ('short_model_ls', 0.0008871478329403455),
#  ('short_model_ltd', 0.0),
#  ('short_model_lucerne', 0.0),
#  ('short_model_lx', 0.0),
#  ('short_model_lx450', 0.0004178940782481988),
#  ('short_model_m', 0.0),
#  ('short_model_m-class', 0.0),
#  ('short_model_m3', 0.0004302502603481467),
#  ('short_model_m35', 0.0),
#  ('short_model_m35s', 0.0004293803948929759),
#  ('short_model_m5', 0.0),
#  ('short_model_macan', 0.0),
#  ('short_model_magnum', 0.0),
#  ('short_model_malibu', 0.0007004729174216762),
#  ('short_model_mallinia', 0.0),
#  ('short_model_marineer,premier', 0.0),
#  ('short_model_mariner', 0.0),
#  ('short_model_mark', 0.0),
#  ('short_model_maserati', 0.0),
#  ('short_model_matrix', 0.0),
#  ('short_model_maxima', 0.0008110621882193097),
#  ('short_model_maximum', 0.0),
#  ('short_model_mazda2', 0.0),
#  ('short_model_mazda3', 0.0011439327317598706),
#  ('short_model_mazda5', 0.0),
#  ('short_model_mazda6', 0.0),
#  ('short_model_mazda6i', 0.0),
#  ('short_model_md-x', 0.0),
#  ('short_model_mdx', 0.0008428520586130325),
#  ('short_model_mercades', 0.0),
#  ('short_model_mercedes-amg', 0.0),
#  ('short_model_metris', 0.0),
#  ('short_model_mg', 0.0),
#  ('short_model_miata', 0.0),
#  ('short_model_milan', 0.0),
#  ('short_model_mirage', 0.0008013262826463476),
#  ('short_model_mkc', 0.0),
#  ('short_model_mks', 0.0),
#  ('short_model_mkt', 0.0),
#  ('short_model_mkx', 0.00041208435266745444),
#  ('short_model_mkz', 0.000757818228587026),
#  ('short_model_ml', 0.0),
#  ('short_model_ml350', 0.0),
#  ('short_model_ml500', 0.0),
#  ('short_model_model', 0.0),
#  ('short_model_monte', 0.0),
#  ('short_model_montero', 0.0),
#  ('short_model_mountaineer', 0.0),
#  ('short_model_mpv', 0.0),
#  ('short_model_mr2', 0.0),
#  ('short_model_murano', 0.0),
#  ('short_model_mustang', 0.002764149475287892),
#  ('short_model_mx-5', 0.0),
#  ('short_model_nautilus', 0.0),
#  ('short_model_navigator', 0.0),
#  ('short_model_neon', 0.0),
#  ('short_model_new', 0.0),
#  ('short_model_newport', 0.0),
#  ('short_model_niro', 0.0),
#  ('short_model_nitro', 0.0),
#  ('short_model_nova', 0.0),
#  ('short_model_nv', 0.0004342231145531336),
#  ('short_model_nv1500', 0.0),
#  ('short_model_nv200', 0.0),
#  ('short_model_nv2500', 0.0),
#  ('short_model_nv2500hd', 0.0),
#  ('short_model_nx', 0.0),
#  ('short_model_nx300', 0.0),
#  ('short_model_oddyssey', 0.0),
#  ('short_model_odyssey', 0.0005950449650910585),
#  ('short_model_oldsmobile', 0.0),
#  ('short_model_optima', 0.0),
#  ('short_model_optimia', 0.0),
#  ('short_model_other', 0.0013157200384164899),
#  ('short_model_outback', 0.0),
#  ('short_model_outlander', 0.0007516993435826452),
#  ('short_model_outlook', 0.0),
#  ('short_model_paceman', 0.0),
#  ('short_model_pacifica', 0.0),
#  ('short_model_panamera', 0.0),
#  ('short_model_panel', 0.0),
#  ('short_model_park', 0.0),
#  ('short_model_passat', 0.0003697327845459976),
#  ('short_model_passport', 0.0),
#  ('short_model_pathfinder', 0.0),
#  ('short_model_patriot', 0.0004137866024266619),
#  ('short_model_phaeton', 0.0),
#  ('short_model_pick', 0.0),
#  ('short_model_pickup', 0.0),
#  ('short_model_pilot', 0.0006684245116122998),
#  ('short_model_plymouth', 0.0003994320144088439),
#  ('short_model_pontaic', 0.0),
#  ('short_model_prelude', 0.0),
#  ('short_model_prius', 0.00032183402410962587),
#  ('short_model_prizm', 0.0),
#  ('short_model_promaster', 0.000917131843894454),
#  ('short_model_protege', 0.0),
#  ('short_model_pt', 0.0),
#  ('short_model_putback', 0.0),
#  ('short_model_q3', 0.0),
#  ('short_model_q5', 0.0),
#  ('short_model_q50', 0.0),
#  ('short_model_q60', 0.0),
#  ('short_model_q7', 0.000343034681107466),
#  ('short_model_q70', 0.0),
#  ('short_model_quattro', 0.0),
#  ('short_model_quest', 0.0),
#  ('short_model_qx50', 0.0),
#  ('short_model_qx56', 0.0),
#  ('short_model_qx60', 0.0),
#  ('short_model_qx70', 0.0),
#  ('short_model_qx80', 0.00042554659746920254),
#  ('short_model_r-class', 0.0),
#  ('short_model_r32', 0.0),
#  ('short_model_rabbit', 0.0),
#  ('short_model_rainier', 0.0),
#  ('short_model_ram1500', 0.0),
#  ('short_model_ram2500', 0.0),
#  ('short_model_ramcharger', 0.0),
#  ('short_model_range', 0.0),
#  ('short_model_ranger', 0.0),
#  ('short_model_rat', 0.0),
#  ('short_model_rav', 0.0),
#  ('short_model_rav4', 0.0004088353097480523),
#  ('short_model_rc', 0.0),
#  ('short_model_rdx', 0.0),
#  ('short_model_reatta', 0.0),
#  ('short_model_rebel', 0.0),
#  ('short_model_regal', 0.0009050019395910672),
#  ('short_model_rendezvous', 0.0),
#  ('short_model_renegade', 0.0004271358208998448),
#  ('short_model_replica', 0.0),
#  ('short_model_ridgeline', 0.0),
#  ('short_model_rio', 0.0),
#  ('short_model_rivera', 0.0),
#  ('short_model_riviera', 0.0),
#  ('short_model_rl', 0.0),
#  ('short_model_rlx', 0.0),
#  ('short_model_roadmaster', 0.0),
#  ('short_model_roadster', 0.0),
#  ('short_model_rogue', 0.0006071852506202507),
#  ('short_model_romeo', 0.0),
#  ('short_model_rondo', 0.0),
#  ('short_model_rouge', 0.0),
#  ('short_model_routan', 0.0),
#  ('short_model_rs', 0.0),
#  ('short_model_rsx', 0.0),
#  ('short_model_rx', 0.0006236423593306993),
#  ('short_model_rx-8', 0.0),
#  ('short_model_rx300', 0.0),
#  ('short_model_rx330', 0.0),
#  ('short_model_rx350', 0.0),
#  ('short_model_rx400h', 0.0),
#  ('short_model_rx7', 0.0),
#  ('short_model_rx8', 0.0),
#  ('short_model_s', 0.0),
#  ('short_model_s-10', 0.0),
#  ('short_model_s-class', 0.00043400010909203855),
#  ('short_model_s/w', 0.0),
#  ('short_model_s10', 0.0),
#  ('short_model_s2000', 0.0),
#  ('short_model_s3', 0.0),
#  ('short_model_s320', 0.0),
#  ('short_model_s4', 0.0),
#  ('short_model_s40', 0.0),
#  ('short_model_s430', 0.0),
#  ('short_model_s5', 0.0005433828297087264),
#  ('short_model_s500', 0.0),
#  ('short_model_s6', 0.0),
#  ('short_model_s60', 0.0),
#  ('short_model_s7', 0.0),
#  ('short_model_s70', 0.0),
#  ('short_model_s8', 0.0),
#  ('short_model_s90', 0.0),
#  ('short_model_saab', 0.0),
#  ('short_model_sable', 0.0),
#  ('short_model_santa', 0.0004142084988152229),
#  ('short_model_sante', 0.0),
#  ('short_model_savana', 0.0),
#  ('short_model_sc', 0.0003347687851771659),
#  ('short_model_sc2', 0.0),
#  ('short_model_sc300', 0.0),
#  ('short_model_school', 0.0),
#  ('short_model_scion', 0.0),
#  ('short_model_sebring', 0.0),
#  ('short_model_sedan', 0.0),
#  ('short_model_sedona', 0.0004113381609921843),
#  ('short_model_seirra', 0.0),
#  ('short_model_sentra', 0.0027801232609098664),
#  ('short_model_sequioa', 0.0),
#  ('short_model_sequoia', 0.0),
#  ('short_model_seville', 0.0),
#  ('short_model_shelby', 0.0),
#  ('short_model_sienna', 0.00041477357106691636),
#  ('short_model_sierra', 0.0024376168186678016),
#  ('short_model_sierra1500', 0.0),
#  ('short_model_silverado', 0.0062841192842969535),
#  ('short_model_sky', 0.0),
#  ('short_model_skylark', 0.0),
#  ('short_model_sl-class', 0.0),
#  ('short_model_sl2', 0.0),
#  ('short_model_sl500', 0.0),
#  ('short_model_sl55', 0.0),
#  ('short_model_sl550', 0.0),
#  ('short_model_slc', 0.0),
#  ('short_model_sle', 0.0),
#  ('short_model_slk', 0.0),
#  ('short_model_slk-class', 0.0),
#  ('short_model_slt', 0.0),
#  ('short_model_smart', 0.0),
#  ('short_model_solara', 0.0),
#  ('short_model_solstice', 0.0),
#  ('short_model_sonata', 0.0),
#  ('short_model_sonic', 0.001192680420644191),
#  ('short_model_sonoma', 0.0),
#  ('short_model_sorento', 0.000409056882225924),
#  ('short_model_sorrento', 0.0),
#  ('short_model_soul', 0.0),
#  ('short_model_soul+', 0.0),
#  ('short_model_spark', 0.0023306729771506536),
#  ('short_model_spectra', 0.0),
#  ('short_model_sport', 0.0),
#  ('short_model_sportage', 0.00043173969185718466),
#  ('short_model_sprinter', 0.0),
#  ('short_model_srx', 0.0),
#  ('short_model_srx-v6', 0.0),
#  ('short_model_srx4', 0.0),
#  ('short_model_srx~awesome', 0.0),
#  ('short_model_ss', 0.0),
#  ('short_model_ssr', 0.00042476644790730904),
#  ('short_model_starcraft', 0.0),
#  ('short_model_step-van', 0.0),
#  ('short_model_stinger', 0.0),
#  ('short_model_stratus', 0.0),
#  ('short_model_sts', 0.0),
#  ('short_model_studebaker', 0.0),
#  ('short_model_suburban', 0.0003711187807262),
#  ('short_model_super', 0.0011551775490852049),
#  ('short_model_supra', 0.0),
#  ('short_model_suv', 0.0),
#  ('short_model_suzuki', 0.0),
#  ('short_model_svx', 0.0),
#  ('short_model_t', 0.0),
#  ('short_model_t-350', 0.0),
#  ('short_model_t-bucket', 0.0),
#  ('short_model_tacoma', 0.0033788631310254255),
#  ('short_model_tahoe', 0.0023690691062669632),
#  ('short_model_tarsus', 0.0),
#  ('short_model_taurus', 0.0011652463183906864),
#  ('short_model_tc5500', 0.0),
#  ('short_model_telluride', 0.0),
#  ('short_model_tercel', 0.0),
#  ('short_model_terrain', 0.0),
#  ('short_model_thing', 0.0),
#  ('short_model_thomas', 0.0),
#  ('short_model_thrift', 0.0),
#  ('short_model_thunderbird', 0.0),
#  ('short_model_tiguan', 0.00021851192390342773),
#  ('short_model_titan', 0.000758837025917931),
#  ('short_model_tl', 0.0),
#  ('short_model_tlx', 0.0),
#  ('short_model_torrent', 0.0),
#  ('short_model_touareg', 0.0),
#  ('short_model_town', 0.0011047616144970799),
#  ('short_model_tracker', 0.0),
#  ('short_model_tractor', 0.0),
#  ('short_model_trailblazer', 0.0),
#  ('short_model_trans', 0.0),
#  ('short_model_transit', 0.0009998416828418157),
#  ('short_model_traverse', 0.0),
#  ('short_model_trax', 0.0015123619583742927),
#  ('short_model_tribeca', 0.00041227302044898626),
#  ('short_model_tribute', 0.0),
#  ('short_model_triumph', 0.0),
#  ('short_model_truck', 0.0004086235064132008),
#  ('short_model_tsx', 0.0),
#  ('short_model_tt', 0.0),
#  ('short_model_tucson', 0.0),
#  ('short_model_tudor', 0.0),
#  ('short_model_tundra', 0.0019456468940616354),
#  ('short_model_uplander', 0.0),
#  ('short_model_utility', 0.0),
#  ('short_model_ux', 0.0),
#  ('short_model_v50', 0.0),
#  ('short_model_v6', 0.0),
#  ('short_model_v60', 0.0),
#  ('short_model_v90', 0.0),
#  ('short_model_van', 0.0),
#  ('short_model_vanagon', 0.0002970775607165777),
#  ('short_model_vandura', 0.0),
#  ('short_model_velar', 0.0),
#  ('short_model_veloster', 0.0),
#  ('short_model_venture', 0.0),
#  ('short_model_venza', 0.0),
#  ('short_model_veracruz', 0.0),
#  ('short_model_verano', 0.00037444275632365),
#  ('short_model_versa', 0.0016186913370454367),
#  ('short_model_vibe', 0.0),
#  ('short_model_villager', 0.0),
#  ('short_model_vnl', 0.0),
#  ('short_model_volt', 0.0),
#  ('short_model_voyager', 0.0),
#  ('short_model_vtx1300c', 0.0),
#  ('short_model_vue', 0.0),
#  ('short_model_w350', 0.0),
#  ('short_model_willys', 0.0005915026432124717),
#  ('short_model_windstar', 0.0),
#  ('short_model_wrangler', 0.009177720322663148),
#  ('short_model_wrx', 0.0),
#  ('short_model_x-3', 0.0),
#  ('short_model_x-type', 0.0),
#  ('short_model_x1', 0.0),
#  ('short_model_x2', 0.0),
#  ('short_model_x3', 0.0),
#  ('short_model_x4', 0.0),
#  ('short_model_x5', 0.0014128544794942378),
#  ('short_model_x6', 0.0),
#  ('short_model_xc', 0.0),
#  ('short_model_xc40', 0.0),
#  ('short_model_xc60', 0.0),
#  ('short_model_xc70', 0.0),
#  ('short_model_xc90', 0.0004407194582059117),
#  ('short_model_xe', 0.0),
#  ('short_model_xf', 0.0),
#  ('short_model_xj', 0.0003342122558061499),
#  ('short_model_xj-series', 0.0),
#  ('short_model_xj8', 0.0),
#  ('short_model_xk8', 0.0),
#  ('short_model_xt4', 0.0),
#  ('short_model_xt5', 0.0),
#  ('short_model_xt6', 0.0),
#  ('short_model_xterra', 0.0),
#  ('short_model_xts', 0.0),
#  ('short_model_xv', 0.0),
#  ('short_model_yaris', 0.00042821637729917246),
#  ('short_model_yukon', 0.0007233192782664501),
#  ('short_model_z', 0.0),
#  ('short_model_z3', 0.00042085987768181843),
#  ('short_model_z4', 0.0),
#  ('short_model_zephyr', 0.0),
#  ('short_model_zx2', 0.0),
#  ('transmission_automatic', 0.0028127752809661787),
#  ('transmission_manual', 0.0009702759107916838),
#  ('transmission_other', 0.001266823598198548),
#  ('region_SF bay area', 0.00042391641436684464),
#  ('region_abilene', 0.00042779168743187175),
#  ('region_akron / canton', 0.0003614443655385027),
#  ('region_albany', 0.0001993546789019142),
#  ('region_albuquerque', 0.0),
#  ('region_altoona-johnstown', 0.0),
#  ('region_amarillo', 0.0),
#  ('region_ames', 0.0),
#  ('region_anchorage / mat-su', 0.0),
#  ('region_ann arbor', 0.0),
#  ('region_annapolis', 0.0),
#  ('region_appleton-oshkosh-FDL', 0.0),
#  ('region_asheville', 0.0),
#  ('region_ashtabula', 0.0),
#  ('region_athens', 0.0),
#  ('region_atlanta', 0.0004194036151292862),
#  ('region_auburn', 0.0),
#  ('region_augusta', 0.0),
#  ('region_austin', 0.0002970775607165777),
#  ('region_bakersfield', 0.0),
#  ('region_baltimore', 0.00022280817053743325),
#  ('region_baton rouge', 0.0),
#  ('region_battle creek', 0.0004409256427477633),
#  ('region_beaumont / port arthur', 0.0),
#  ('region_bellingham', 0.0),
#  ('region_bemidji', 0.0),
#  ('region_bend', 0.000501318383709225),
#  ('region_billings', 0.0003713469508957221),
#  ('region_binghamton', 0.0),
#  ('region_birmingham', 0.0),
#  ('region_bismarck', 0.0),
#  ('region_bloomington', 0.0),
#  ('region_bloomington-normal', 0.0004075129148090438),
#  ('region_boise', 0.0007791531732440383),
#  ('region_boone', 0.0),
#  ('region_boston', 0.00035649307285989313),
#  ('region_boulder', 0.00038110296699695926),
#  ('region_bowling green', 0.0),
#  ('region_bozeman', 0.0),
#  ('region_brainerd', 0.0),
#  ('region_brownsville', 0.0),
#  ('region_brunswick', 0.0),
#  ('region_buffalo', 0.0),
#  ...]

# %%
f_imp_list.sort(key = lambda x: x[1], reverse=True)

# %%
f_imp_list
# Out:
# [('year_std', 0.22128740407133865),
#  ('std_scaled_odometer', 0.07976968187721656),
#  ('model_len_std', 0.07873061412074053),
#  ('desc_len_std', 0.06812597488103386),
#  ('lat_std', 0.04015134882966277),
#  ('long_std', 0.03812066844638895),
#  ('x0_diesel', 0.033097961449185156),
#  ('id', 0.03158202261840626),
#  ('diff_years_std', 0.023318267030183797),
#  ('dayofweek_std', 0.015446646949240084),
#  ('short_model_wrangler', 0.009177720322663148),
#  ('manufacturer_kia', 0.009142192303278451),
#  ('manufacturer_ram', 0.008979406064711346),
#  ('model_word_count_std', 0.008545448593160644),
#  ('short_model_silverado', 0.0062841192842969535),
#  ('short_model_f-150', 0.006112665483013556),
#  ('manufacturer_hyundai', 0.005663759938057568),
#  ('manufacturer_gmc', 0.005541462547103364),
#  ('model_in_desc_std', 0.005264499360151503),
#  ('manufacturer_volkswagen', 0.005086759992675917),
#  ('short_model_Scion', 0.004865746378858322),
#  ('manufacturer_mercedes-benz', 0.004614266590743073),
#  ('manufacturer_dodge', 0.004583981889895085),
#  ('manufacturer_ford', 0.00415866470115369),
#  ('manufacturer_rover', 0.0041338867845592394),
#  ('manufacturer_bmw', 0.003976334069270213),
#  ('manufacturer_chevrolet', 0.00372729139763921),
#  ('is_chevrolet', 0.0036328771792079216),
#  ('short_model_tacoma', 0.0033788631310254255),
#  ('short_model_f-250', 0.003001630284946771),
#  ('manufacturer_honda', 0.0029211626803207235),
#  ('short_model_f150', 0.0028381501048308114),
#  ('transmission_automatic', 0.0028127752809661787),
#  ('short_model_sentra', 0.0027801232609098664),
#  ('short_model_mustang', 0.002764149475287892),
#  ('month_std', 0.0027325830629483785),
#  ('x0_gas', 0.002624342857727372),
#  ('manufacturer_nissan', 0.0025848633466784587),
#  ('short_model_jetta', 0.0025695856050929216),
#  ('short_model_corolla', 0.0025530887672715486),
#  ('is_toyota', 0.0024952016341785142),
#  ('short_model_focus', 0.0024570664292030927),
#  ('short_model_sierra', 0.0024376168186678016),
#  ('short_model_tahoe', 0.0023690691062669632),
#  ('manufacturer_other', 0.002351160669720267),
#  ('short_model_spark', 0.0023306729771506536),
#  ('state_oh', 0.002309143066099669),
#  ('short_model_escape', 0.0022896528159364357),
#  ('title_status_rebuilt', 0.0022622986744211537),
#  ('short_model_cruze', 0.0021785661028214665),
#  ('short_model_4runner', 0.0021040569753639133),
#  ('short_model_fj', 0.0019827623767689996),
#  ('short_model_tundra', 0.0019456468940616354),
#  ('manufacturer_mitsubishi', 0.0018494441552318515),
#  ('state_il', 0.0018291207470480895),
#  ('is_ford', 0.001797849737979432),
#  ('title_status_clean', 0.0017906323164170036),
#  ('short_model_escalade', 0.0017808276175028724),
#  ('state_nm', 0.0017484974698145836),
#  ('short_model_f250', 0.0016949566264939943),
#  ('manufacturer_buick', 0.0016361770743272364),
#  ('region_fort collins / north CO', 0.0016238777753789706),
#  ('short_model_versa', 0.0016186913370454367),
#  ('region_flint', 0.0015646036616490534),
#  ('short_model_colorado', 0.0015455319755306191),
#  ('state_mi', 0.001544455856590864),
#  ('short_model_trax', 0.0015123619583742927),
#  ('short_model_grand', 0.0014989074046955855),
#  ('manufacturer_cadillac', 0.0014750639125042792),
#  ('manufacturer_jeep', 0.0014573038767463778),
#  ('short_model_x5', 0.0014128544794942378),
#  ('state_tx', 0.0013904030182369234),
#  ('short_model_elantra', 0.0013864423281385954),
#  ('x0_hybrid', 0.0013858022386644174),
#  ('short_model_express', 0.0013236306142098788),
#  ('short_model_other', 0.0013157200384164899),
#  ('short_model_g', 0.0012690028497089891),
#  ('transmission_other', 0.001266823598198548),
#  ('state_ky', 0.001222186962982755),
#  ('state_id', 0.001197298206432025),
#  ('region_minneapolis / st paul', 0.0011958074529234276),
#  ('short_model_sonic', 0.001192680420644191),
#  ('state_fl', 0.0011883102428663108),
#  ('region_lakeland', 0.0011764382290191105),
#  ('short_model_fusion', 0.0011751522216655397),
#  ('short_model_taurus', 0.0011652463183906864),
#  ('state_co', 0.0011652131523291742),
#  ('state_tn', 0.0011562393698344071),
#  ('short_model_super', 0.0011551775490852049),
#  ('region_detroit metro', 0.00115328103082683),
#  ('region_tucson', 0.0011482308504271934),
#  ('short_model_mazda3', 0.0011439327317598706),
#  ('manufacturer_lexus', 0.001137459443293465),
#  ('region_pittsburgh', 0.0011368841015776698),
#  ('short_model_impreza', 0.001114006524469102),
#  ('short_model_golf', 0.001109068313848265),
#  ('short_model_f-350', 0.0011081106692366364),
#  ('short_model_town', 0.0011047616144970799),
#  ('state_nv', 0.0011024816318096601),
#  ('short_model_altima', 0.0010981537775514947),
#  ('region_south florida', 0.0010939359438080728),
#  ('short_model_avalanche', 0.001091507141819505),
#  ('region_rochester', 0.00109045247594717),
#  ('manufacturer_toyota', 0.0010831945640744378),
#  ('region_dallas / fort worth', 0.0010422974951364557),
#  ('short_model_1500', 0.00103455870450748),
#  ('manufacturer_chrysler', 0.001015519104970926),
#  ('state_ny', 0.001005819741283271),
#  ('short_model_transit', 0.0009998416828418157),
#  ('short_model_corvette', 0.0009957858969400686),
#  ('region_wenatchee', 0.0009887060538278304),
#  ('transmission_manual', 0.0009702759107916838),
#  ('short_model_land', 0.0009270182405919849),
#  ('short_model_hummer', 0.0009227401667930807),
#  ('state_nc', 0.0009195291501140262),
#  ('short_model_promaster', 0.000917131843894454),
#  ('manufacturer_mazda', 0.0009158588483670285),
#  ('short_model_regal', 0.0009050019395910672),
#  ('region_san antonio', 0.0008927809219407675),
#  ('short_model_ls', 0.0008871478329403455),
#  ('region_fresno / madera', 0.0008853875184734894),
#  ('region_little rock', 0.0008672587788152626),
#  ('state_md', 0.0008628752786267868),
#  ('short_model_fit', 0.0008582988981001105),
#  ('short_model_gto', 0.0008485131539757174),
#  ('short_model_328xi', 0.000844576270370527),
#  ('short_model_mdx', 0.0008428520586130325),
#  ('short_model_f650', 0.0008395216748567141),
#  ('region_orlando', 0.0008375341332594497),
#  ('region_olympic peninsula', 0.0008335103581763029),
#  ('state_sd', 0.0008328781612946913),
#  ('manufacturer_fiat', 0.0008269082904487314),
#  ('region_raleigh / durham / CH', 0.0008252467613256621),
#  ('region_omaha / council bluffs', 0.000823265289540389),
#  ("region_spokane / coeur d'alene", 0.0008192895116294135),
#  ('region_portland', 0.0008166027664741024),
#  ('short_model_maxima', 0.0008110621882193097),
#  ('state_mt', 0.0008085418365485546),
#  ('region_indianapolis', 0.0008076902447802258),
#  ('region_philadelphia', 0.0008061463563974593),
#  ('short_model_mirage', 0.0008013262826463476),
#  ('state_az', 0.0007996972457067197),
#  ('x0_other', 0.000798036576408809),
#  ('region_st cloud', 0.0007891143339724421),
#  ('short_model_a4', 0.0007870877769526716),
#  ('state_pa', 0.000784284760291765),
#  ('region_inland empire', 0.0007827005451400418),
#  ('region_boise', 0.0007791531732440383),
#  ('region_prescott', 0.0007755543176911141),
#  ('title_status_lien', 0.0007633673962219024),
#  ('short_model_gx', 0.0007628859770442962),
#  ('short_model_titan', 0.000758837025917931),
#  ('region_roanoke', 0.0007582242716368827),
#  ('short_model_mkz', 0.000757818228587026),
#  ('region_yakima', 0.0007534746255030679),
#  ('short_model_outlander', 0.0007516993435826452),
#  ('short_model_Flexible', 0.0007427980664340525),
#  ('state_ks', 0.0007426939017914443),
#  ('state_nj', 0.0007415098970204724),
#  ('manufacturer_acura', 0.0007388594101201041),
#  ('region_los angeles', 0.0007373568793355304),
#  ('short_model_impala', 0.0007352650261531871),
#  ('manufacturer_volvo', 0.0007281299767568721),
#  ('short_model_yukon', 0.0007233192782664501),
#  ('state_ms', 0.0007155067172600588),
#  ('short_model_e-350', 0.0007127535996839997),
#  ('region_kansas city, MO', 0.0007124298206997197),
#  ('state_wi', 0.0007083003031880511),
#  ('short_model_malibu', 0.0007004729174216762),
#  ('manufacturer_mini', 0.0006967720224425804),
#  ('x0_electric', 0.0006947852275420483),
#  ('short_model_e-series', 0.0006918532295582757),
#  ('short_model_cooper', 0.0006903211360097658),
#  ('short_model_pilot', 0.0006684245116122998),
#  ('region_ft myers / SW florida', 0.000666118008811705),
#  ('region_reno / tahoe', 0.0006636210188850512),
#  ('short_model_PROGRAMS', 0.0006581410575874951),
#  ('short_model_camry', 0.0006439800108542663),
#  ('title_status_salvage', 0.000634381573941951),
#  ('state_ia', 0.0006320829847673604),
#  ('short_model_encore', 0.0006314375788163085),
#  ('short_model_rx', 0.0006236423593306993),
#  ('short_model_es', 0.0006230376620583781),
#  ('region_chico', 0.000614626812315869),
#  ('short_model_f-250sd', 0.0006139008617778531),
#  ('short_model_rogue', 0.0006071852506202507),
#  ('state_va', 0.0006036282579355975),
#  ('short_model_odyssey', 0.0005950449650910585),
#  ('age_category_average', 0.0005941551214331554),
#  ('short_model_willys', 0.0005915026432124717),
#  ('manufacturer_subaru', 0.0005704977241174893),
#  ('region_colorado springs', 0.0005514502220801468),
#  ('short_model_s5', 0.0005433828297087264),
#  ('region_hartford', 0.0005396717850083009),
#  ('state_wa', 0.0005198857312540109),
#  ('region_ventura county', 0.0005160442110723303),
#  ('region_bend', 0.000501318383709225),
#  ('region_redding', 0.00048118705843738676),
#  ('short_model_civic', 0.0004581553290271888),
#  ('short_model_gla-class', 0.0004510634355021308),
#  ('region_battle creek', 0.0004409256427477633),
#  ('short_model_xc90', 0.0004407194582059117),
#  ('short_model_is', 0.0004377985105296935),
#  ('region_texarkana', 0.0004372084855828874),
#  ('short_model_edge', 0.000436332667302474),
#  ('short_model_nv', 0.0004342231145531336),
#  ('short_model_s-class', 0.00043400010909203855),
#  ('short_model_g37', 0.0004329252529728255),
#  ('short_model_eurovan', 0.00043253345502062895),
#  ('state_sc', 0.00043250997810207625),
#  ('short_model_sportage', 0.00043173969185718466),
#  ('region_lawrence', 0.0004314512421612664),
#  ('region_saginaw-midland-baycity', 0.0004311386004188264),
#  ('short_model_ecosport', 0.00043074034259520485),
#  ('region_visalia-tulare', 0.0004305718520500224),
#  ('short_model_m3', 0.0004302502603481467),
#  ('short_model_e-golf', 0.0004298292450102766),
#  ('short_model_m35s', 0.0004293803948929759),
#  ('region_lexington', 0.0004293803948929759),
#  ('short_model_yaris', 0.00042821637729917246),
#  ('region_abilene', 0.00042779168743187175),
#  ('region_worcester / central MA', 0.00042779168743187175),
#  ('short_model_renegade', 0.0004271358208998448),
#  ('state_ma', 0.0004262417175498725),
#  ('short_model_qx80', 0.00042554659746920254),
#  ('short_model_camaro', 0.000425361052844191),
#  ('state_in', 0.000425156552338015),
#  ('region_winston-salem', 0.00042501775729442815),
#  ('short_model_ssr', 0.00042476644790730904),
#  ('region_SF bay area', 0.00042391641436684464),
#  ('region_southern illinois', 0.00042285738522009357),
#  ('short_model_k900', 0.00042216284943934743),
#  ('short_model_325is', 0.00042211523055373445),
#  ('short_model_davidson', 0.0004218548426910259),
#  ('region_nashville', 0.0004210155787094477),
#  ('short_model_z3', 0.00042085987768181843),
#  ('short_model_330xi', 0.00042006119924662517),
#  ('short_model_3-series', 0.00041995225357931094),
#  ('region_la crosse', 0.00041968922594467356),
#  ('region_atlanta', 0.0004194036151292862),
#  ('short_model_F250', 0.0004190989217499753),
#  ('short_model_lx450', 0.0004178940782481988),
#  ('region_missoula', 0.00041633264496299143),
#  ('region_san diego', 0.00041613364376132746),
#  ('short_model_AM', 0.00041590858500320884),
#  ('state_mn', 0.00041590858500320884),
#  ('short_model_sienna', 0.00041477357106691636),
#  ('short_model_santa', 0.0004142084988152229),
#  ('short_model_CLICK', 0.0004138231241984923),
#  ('short_model_patriot', 0.0004137866024266619),
#  ('is_audi', 0.0004135369574176561),
#  ('short_model_i3', 0.0004131608979428074),
#  ('region_southern maryland', 0.00041279668232516165),
#  ('short_model_cayenne', 0.0004127855506578767),
#  ('short_model_tribeca', 0.00041227302044898626),
#  ('short_model_mkx', 0.00041208435266745444),
#  ('region_tri-cities', 0.0004119062569999708),
#  ('short_model_cc', 0.0004113381609921843),
#  ('short_model_sedona', 0.0004113381609921843),
#  ('region_rockford', 0.0004113381609921843),
#  ('region_santa fe / taos', 0.00041075304269774327),
#  ('region_dayton / springfield', 0.00041070972769066824),
#  ('region_youngstown', 0.00041029817878438245),
#  ('region_lansing', 0.0004098198331957291),
#  ('short_model_sorento', 0.000409056882225924),
#  ('short_model_rav4', 0.0004088353097480523),
#  ('short_model_truck', 0.0004086235064132008),
#  ('short_model_durango', 0.0004084816459852943),
#  ('short_model_g6', 0.0004084816459852943),
#  ('region_savannah / hinesville', 0.00040790075517844283),
#  ('region_bloomington-normal', 0.0004075129148090438),
#  ('short_model_Chevorlet', 0.000406070302148309),
#  ('short_model_frontier', 0.00040584065035431216),
#  ('short_model_Plymouth', 0.00040510576461351503),
#  ('region_danville', 0.00040510576461351503),
#  ('short_model_2500', 0.0004047702972470453),
#  ('short_model_forte', 0.00040470065884890075),
#  ('short_model_canyon', 0.0004037805455301814),
#  ('region_chicago', 0.0004035788032277414),
#  ('short_model_cherokee', 0.0004031249338713303),
#  ('region_elmira-corning', 0.0004026274705241152),
#  ('region_madison', 0.0004026182730764139),
#  ('region_laredo', 0.0004015669096582711),
#  ('region_santa barbara', 0.00040105470696738),
#  ('short_model_c-hr', 0.00040097322017564833),
#  ('region_east oregon', 0.0003999663631221492),
#  ('short_model_genesis', 0.0003994320144088439),
#  ('short_model_plymouth', 0.0003994320144088439),
#  ('short_model_excursion', 0.0003988943753081226),
#  ('short_model_e350', 0.0003977238373472234),
#  ('short_model_dart', 0.00039668678441625086),
#  ('region_tuscaloosa', 0.000396636080782695),
#  ('region_south jersey', 0.0003948846345524969),
#  ('region_mankato', 0.00039196258601439634),
#  ('short_model_HUMMER', 0.0003914403818003544),
#  ('region_columbus', 0.00039017193971078827),
#  ('short_model_2002', 0.0003899142984405082),
#  ('short_model_freestyle', 0.0003899142984405082),
#  ('short_model_328i', 0.0003896887840978581),
#  ('region_delaware', 0.00038890861217279513),
#  ('state_ok', 0.00038842632285329524),
#  ('short_model_428', 0.0003876173069916691),
#  ('region_zanesville / cambridge', 0.0003841367664749593),
#  ('short_model_1966', 0.00038346458824074065),
#  ('region_new york city', 0.0003830178550667307),
#  ('region_cincinnati', 0.0003819568637784571),
#  ('region_jackson', 0.0003819568637784571),
#  ('region_norfolk / hampton roads', 0.0003819568637784571),
#  ('manufacturer_infiniti', 0.0003819568637784571),
#  ('state_me', 0.00038117409554653154),
#  ('region_boulder', 0.00038110296699695926),
#  ('region_houston', 0.00037994656449541253),
#  ('state_nh', 0.0003799164959163924),
#  ('region_scottsbluff / panhandle', 0.000379706749706123),
#  ('short_model_verano', 0.00037444275632365),
#  ('short_model_explorer', 0.00037251104792047424),
#  ('region_palm springs', 0.0003720359062777189),
#  ('short_model_isf', 0.00037181258970562375),
#  ('region_billings', 0.0003713469508957221),
#  ('region_southwest michigan', 0.0003713469508957221),
#  ('short_model_suburban', 0.0003711187807262),
#  ('short_model_passat', 0.0003697327845459976),
#  ('short_model_highlander', 0.0003661803846223917),
#  ('region_akron / canton', 0.0003614443655385027),
#  ('short_model_challenger', 0.00035649307285989313),
#  ('region_boston', 0.00035649307285989313),
#  ('age_category_old', 0.00035649307285989313),
#  ('state_ak', 0.00035214559636160154),
#  ('region_washington, DC', 0.00035103395529116995),
#  ('short_model_q7', 0.000343034681107466),
#  ('short_model_ilx', 0.0003364770226184638),
#  ('short_model_sc', 0.0003347687851771659),
#  ('short_model_3', 0.0003342122558061499),
#  ('short_model_e-150', 0.0003342122558061499),
#  ('short_model_xj', 0.0003342122558061499),
#  ('region_new haven', 0.0003342122558061499),
#  ('region_north jersey', 0.0003342122558061499),
#  ('state_al', 0.0003342122558061499),
#  ('region_susanville', 0.00032679809981580617),
#  ('short_model_prius', 0.00032183402410962587),
#  ('short_model_equinox', 0.0002970775607165777),
#  ('short_model_vanagon', 0.0002970775607165777),
#  ('region_austin', 0.0002970775607165777),
#  ('region_denver', 0.0002970775607165777),
#  ('region_milwaukee', 0.0002970775607165777),
#  ('region_north mississippi', 0.0002970775607165777),
#  ('region_rhode island', 0.0002970775607165777),
#  ('region_tampa bay area', 0.0002970775607165777),
#  ('state_mo', 0.0002970775607165777),
#  ('state_ca', 0.0002896506216986633),
#  ('short_model_fiesta', 0.0002864676478338427),
#  ('region_modesto', 0.00023766204857326214),
#  ('region_baltimore', 0.00022280817053743325),
#  ('region_knoxville', 0.00022280817053743325),
#  ('region_orange county', 0.00022280817053743325),
#  ('manufacturer_audi', 0.00022280817053743325),
#  ('state_vt', 0.00022280817053743325),
#  ('short_model_leaf', 0.00022193952269908052),
#  ('region_seattle-tacoma', 0.00022021572058102793),
#  ('region_twin falls', 0.00021896686821545926),
#  ('short_model_tiguan', 0.00021851192390342773),
#  ('manufacturer_lincoln', 0.00021730673422786737),
#  ('region_pueblo', 0.00021579707356979709),
#  ('region_kalispell', 0.00021175852611728796),
#  ('region_albany', 0.0001993546789019142),
#  ('region_phoenix', 0.00014616848067171867),
#  ('region_charlotte', 0.0001433743767862846),
#  ('region_sacramento', 0.00014210625337360538),
#  ('region_st louis, MO', 0.00010775149230908806),
#  ('region_central NJ', 8.599754833790955e-05),
#  ('short_model_-benz', 0.0),
#  ('short_model_1', 0.0),
#  ('short_model_124', 0.0),
#  ('short_model_128i', 0.0),
#  ('short_model_135i', 0.0),
#  ('short_model_163869', 0.0),
#  ('short_model_1928', 0.0),
#  ('short_model_1951', 0.0),
#  ('short_model_1954', 0.0),
#  ('short_model_1960s', 0.0),
#  ('short_model_1968', 0.0),
#  ('short_model_1972', 0.0),
#  ('short_model_1977', 0.0),
#  ('short_model_1978', 0.0),
#  ('short_model_198.5', 0.0),
#  ('short_model_1988', 0.0),
#  ('short_model_1994', 0.0),
#  ('short_model_1999', 0.0),
#  ('short_model_2', 0.0),
#  ('short_model_200', 0.0),
#  ('short_model_2000', 0.0),
#  ('short_model_2006', 0.0),
#  ('short_model_2007', 0.0),
#  ('short_model_2008', 0.0),
#  ('short_model_2009', 0.0),
#  ('short_model_2012', 0.0),
#  ('short_model_2015', 0.0),
#  ('short_model_2016', 0.0),
#  ('short_model_2017', 0.0),
#  ('short_model_2018', 0.0),
#  ('short_model_210', 0.0),
#  ('short_model_240', 0.0),
#  ('short_model_2500hd', 0.0),
#  ('short_model_280zx', 0.0),
#  ('short_model_3-window', 0.0),
#  ('short_model_3.2', 0.0),
#  ('short_model_300', 0.0),
#  ('short_model_300-series', 0.0),
#  ('short_model_300c', 0.0),
#  ('short_model_300s', 0.0),
#  ('short_model_300zx', 0.0),
#  ('short_model_3100', 0.0),
#  ('short_model_318i', 0.0),
#  ('short_model_320i', 0.0),
#  ('short_model_323i', 0.0),
#  ('short_model_325ci', 0.0),
#  ('short_model_325i', 0.0),
#  ('short_model_325xi', 0.0),
#  ('short_model_328', 0.0),
#  ('short_model_328ci', 0.0),
#  ('short_model_328d', 0.0),
#  ('short_model_330i', 0.0),
#  ('short_model_335i', 0.0),
#  ('short_model_335xi', 0.0),
#  ('short_model_350', 0.0),
#  ('short_model_3500', 0.0),
#  ('short_model_3500hd', 0.0),
#  ('short_model_350z', 0.0),
#  ('short_model_370z', 0.0),
#  ('short_model_380sl', 0.0),
#  ('short_model_3i', 0.0),
#  ('short_model_4', 0.0),
#  ('short_model_4-runner', 0.0),
#  ('short_model_430i', 0.0),
#  ('short_model_435i', 0.0),
#  ('short_model_440xi', 0.0),
#  ('short_model_4500', 0.0),
#  ('short_model_4x4', 0.0),
#  ('short_model_5', 0.0),
#  ('short_model_5-series', 0.0),
#  ('short_model_50', 0.0),
#  ('short_model_500', 0.0),
#  ('short_model_500c', 0.0),
#  ('short_model_500l', 0.0),
#  ('short_model_500x', 0.0),
#  ('short_model_525i', 0.0),
#  ('short_model_528i', 0.0),
#  ('short_model_528xi', 0.0),
#  ('short_model_530', 0.0),
#  ('short_model_530i', 0.0),
#  ('short_model_535i', 0.0),
#  ('short_model_535xi', 0.0),
#  ('short_model_540i', 0.0),
#  ('short_model_545i', 0.0),
#  ('short_model_5500', 0.0),
#  ('short_model_5500hd', 0.0),
#  ('short_model_550i', 0.0),
#  ('short_model_5th', 0.0),
#  ('short_model_6', 0.0),
#  ('short_model_640', 0.0),
#  ('short_model_645ci', 0.0),
#  ('short_model_650i', 0.0),
#  ('short_model_650xi', 0.0),
#  ('short_model_7', 0.0),
#  ('short_model_750', 0.0),
#  ('short_model_750i', 0.0),
#  ('short_model_750xi', 0.0),
#  ('short_model_86', 0.0),
#  ('short_model_911', 0.0),
#  ('short_model_914', 0.0),
#  ('short_model_928', 0.0),
#  ('short_model_944', 0.0),
#  ('short_model_ACURA*', 0.0),
#  ('short_model_ALL', 0.0),
#  ('short_model_AMC', 0.0),
#  ('short_model_ASC', 0.0),
#  ('short_model_Acuarea', 0.0),
#  ('short_model_American', 0.0),
#  ('short_model_BUY', 0.0),
#  ('short_model_Bentley', 0.0),
#  ('short_model_Blue', 0.0),
#  ('short_model_Buicks', 0.0),
#  ('short_model_C', 0.0),
#  ('short_model_CHEVORLET', 0.0),
#  ('short_model_Champion', 0.0),
#  ('short_model_Chevey', 0.0),
#  ('short_model_Comanche', 0.0),
#  ('short_model_Comet', 0.0),
#  ('short_model_D7FH173552', 0.0),
#  ('short_model_DODGE1500', 0.0),
#  ('short_model_Diahatsu', 0.0),
#  ('short_model_E46', 0.0),
#  ('short_model_EASY', 0.0),
#  ('short_model_Eagle', 0.0),
#  ('short_model_Emergency', 0.0),
#  ('short_model_F-250', 0.0),
#  ('short_model_FORD*', 0.0),
#  ('short_model_FORD/RANGER', 0.0),
#  ('short_model_FREIGHTLINER', 0.0),
#  ('short_model_FRRV', 0.0),
#  ('short_model_FordE350', 0.0),
#  ('short_model_Freightliner', 0.0),
#  ('short_model_Frtlner', 0.0),
#  ('short_model_GCM', 0.0),
#  ('short_model_GEHL', 0.0),
#  ('short_model_GMC,', 0.0),
#  ('short_model_GMX', 0.0),
#  ('short_model_GRAND', 0.0),
#  ('short_model_GULF', 0.0),
#  ('short_model_Genesis', 0.0),
#  ('short_model_Gx', 0.0),
#  ('short_model_HINO', 0.0),
#  ('short_model_Hino', 0.0),
#  ('short_model_Hobda', 0.0),
#  ('short_model_Hot', 0.0),
#  ('short_model_Hummer', 0.0),
#  ('short_model_IC', 0.0),
#  ('short_model_INTERNATIONAL', 0.0),
#  ('short_model_International', 0.0),
#  ('short_model_Isizu', 0.0),
#  ('short_model_Isuzu', 0.0),
#  ('short_model_JM1BK32F871604924', 0.0),
#  ('short_model_Janesville', 0.0),
#  ('short_model_Jauguar', 0.0),
#  ('short_model_Jayco', 0.0),
#  ('short_model_Kaiser', 0.0),
#  ('short_model_Lotus', 0.0),
#  ('short_model_MASERATI', 0.0),
#  ('short_model_MERCUTY', 0.0),
#  ('short_model_MERDECES', 0.0),
#  ('short_model_MGB', 0.0),
#  ('short_model_MITUSBISHI', 0.0),
#  ('short_model_MV-1', 0.0),
#  ('short_model_Maserati', 0.0),
#  ('short_model_Minin', 0.0),
#  ('short_model_Nascar', 0.0),
#  ('short_model_OLDSMOBILE', 0.0),
#  ('short_model_PLYMOUTH', 0.0),
#  ('short_model_Peterbilt', 0.0),
#  ('short_model_Pierce', 0.0),
#  ('short_model_QX', 0.0),
#  ('short_model_S60', 0.0),
#  ('short_model_SCION', 0.0),
#  ('short_model_SL', 0.0),
#  ('short_model_Saab', 0.0),
#  ('short_model_Sea', 0.0),
#  ('short_model_Sterling', 0.0),
#  ('short_model_Studebaker', 0.0),
#  ('short_model_Suzuki', 0.0),
#  ('short_model_THOMAS', 0.0),
#  ('short_model_Thomas', 0.0),
#  ('short_model_Town', 0.0),
#  ('short_model_Triumph', 0.0),
#  ('short_model_Voltswagon', 0.0),
#  ('short_model_Xx', 0.0),
#  ('short_model_a-class', 0.0),
#  ('short_model_a3', 0.0),
#  ('short_model_a3,', 0.0),
#  ('short_model_a5', 0.0),
#  ('short_model_a6', 0.0),
#  ('short_model_a7', 0.0),
#  ('short_model_a8', 0.0),
#  ('short_model_acadia', 0.0),
#  ('short_model_accent', 0.0),
#  ('short_model_accord', 0.0),
#  ('short_model_all', 0.0),
#  ('short_model_allante', 0.0),
#  ('short_model_allroad', 0.0),
#  ('short_model_am', 0.0),
#  ('short_model_amc', 0.0),
#  ('short_model_arcadia', 0.0),
#  ('short_model_armada', 0.0),
#  ('short_model_arteon', 0.0),
#  ('short_model_ascent', 0.0),
#  ('short_model_aspen', 0.0),
#  ('short_model_astra', 0.0),
#  ('short_model_astro', 0.0),
#  ('short_model_atlas', 0.0),
#  ('short_model_ats', 0.0),
#  ('short_model_aura', 0.0),
#  ('short_model_autobiography', 0.0),
#  ('short_model_avalon', 0.0),
#  ('short_model_avanger', 0.0),
#  ('short_model_avenger', 0.0),
#  ('short_model_aveo', 0.0),
#  ('short_model_aviator', 0.0),
#  ('short_model_azera', 0.0),
#  ('short_model_aztek', 0.0),
#  ('short_model_b-class', 0.0),
#  ('short_model_b-series', 0.0),
#  ('short_model_b2200', 0.0),
#  ('short_model_b2300', 0.0),
#  ('short_model_b2600i', 0.0),
#  ('short_model_baja', 0.0),
#  ('short_model_beetle', 0.0),
#  ('short_model_bel', 0.0),
#  ('short_model_belair', 0.0),
#  ('short_model_benz', 0.0),
#  ('short_model_blackwood', 0.0),
#  ('short_model_blazer', 0.0),
#  ('short_model_blue', 0.0),
#  ('short_model_bolt', 0.0),
#  ('short_model_bonanza', 0.0),
#  ('short_model_bonneville', 0.0),
#  ('short_model_boxster', 0.0),
#  ('short_model_bronco', 0.0),
#  ('short_model_brz', 0.0),
#  ('short_model_bug', 0.0),
#  ('short_model_bus', 0.0),
#  ('short_model_c', 0.0),
#  ('short_model_c-10', 0.0),
#  ('short_model_c-7500', 0.0),
#  ('short_model_c-class', 0.0),
#  ('short_model_c-max', 0.0),
#  ('short_model_c/k', 0.0),
#  ('short_model_c10', 0.0),
#  ('short_model_c250', 0.0),
#  ('short_model_c280', 0.0),
#  ('short_model_c30', 0.0),
#  ('short_model_c300', 0.0),
#  ('short_model_c4500', 0.0),
#  ('short_model_c5500', 0.0),
#  ('short_model_c60', 0.0),
#  ('short_model_c6500', 0.0),
#  ('short_model_c70', 0.0),
#  ('short_model_c8500', 0.0),
#  ('short_model_cabellero', 0.0),
#  ('short_model_cabrio', 0.0),
#  ('short_model_caddilac', 0.0),
#  ('short_model_cadenza', 0.0),
#  ('short_model_caliber', 0.0),
#  ('short_model_camary', 0.0),
#  ('short_model_camero', 0.0),
#  ('short_model_capri', 0.0),
#  ('short_model_caprice', 0.0),
#  ('short_model_captiva', 0.0),
#  ('short_model_caravan', 0.0),
#  ('short_model_caravan/grand', 0.0),
#  ('short_model_cargo', 0.0),
#  ('short_model_cascada', 0.0),
#  ('short_model_cavalier', 0.0),
#  ('short_model_cayman', 0.0),
#  ('short_model_cc300', 0.0),
#  ('short_model_cc4500', 0.0),
#  ('short_model_century', 0.0),
#  ('short_model_certified', 0.0),
#  ('short_model_charger', 0.0),
#  ('short_model_chevelle', 0.0),
#  ('short_model_chevorlet', 0.0),
#  ('short_model_chryler', 0.0),
#  ('short_model_chysler', 0.0),
#  ('short_model_city', 0.0),
#  ('short_model_cj-5', 0.0),
#  ('short_model_cj2a', 0.0),
#  ('short_model_cj5', 0.0),
#  ('short_model_cj7', 0.0),
#  ('short_model_cj8', 0.0),
#  ('short_model_cl-class', 0.0),
#  ('short_model_cla', 0.0),
#  ('short_model_cla-class', 0.0),
#  ('short_model_clarity', 0.0),
#  ('short_model_classic', 0.0),
#  ('short_model_classuc', 0.0),
#  ('short_model_clk', 0.0),
#  ('short_model_clk-class', 0.0),
#  ('short_model_clk350', 0.0),
#  ('short_model_cls-class', 0.0),
#  ('short_model_cls550', 0.0),
#  ('short_model_clubman', 0.0),
#  ('short_model_cmax', 0.0),
#  ('short_model_cobalt', 0.0),
#  ('short_model_colbalt', 0.0),
#  ('short_model_comet', 0.0),
#  ('short_model_commander', 0.0),
#  ('short_model_compass', 0.0),
#  ('short_model_concorde', 0.0),
#  ('short_model_conquest', 0.0),
#  ('short_model_continental', 0.0),
#  ('short_model_convertible', 0.0),
#  ('short_model_corsair', 0.0),
#  ('short_model_cougar', 0.0),
#  ('short_model_country', 0.0),
#  ('short_model_countryman', 0.0),
#  ('short_model_coupe', 0.0),
#  ('short_model_cr-v', 0.0),
#  ('short_model_crew', 0.0),
#  ('short_model_crossfire', 0.0),
#  ('short_model_crosstour', 0.0),
#  ('short_model_crosstrek', 0.0),
#  ('short_model_crown', 0.0),
#  ('short_model_crv', 0.0),
#  ('short_model_crz', 0.0),
#  ('short_model_ct', 0.0),
#  ('short_model_ct4', 0.0),
#  ('short_model_ct5', 0.0),
#  ('short_model_ct6', 0.0),
#  ('short_model_cts', 0.0),
#  ('short_model_cts-v', 0.0),
#  ('short_model_cts4', 0.0),
#  ('short_model_cube', 0.0),
#  ('short_model_cvr', 0.0),
#  ('short_model_cx-3', 0.0),
#  ('short_model_cx-5', 0.0),
#  ('short_model_cx-7', 0.0),
#  ('short_model_cx-9', 0.0),
#  ('short_model_cx7', 0.0),
#  ('short_model_cx9', 0.0),
#  ('short_model_d50', 0.0),
#  ('short_model_dakota', 0.0),
#  ('short_model_dealer*', 0.0),
#  ('short_model_defender', 0.0),
#  ('short_model_deisel', 0.0),
#  ('short_model_deluxe', 0.0),
#  ('short_model_denali', 0.0),
#  ('short_model_deville', 0.0),
#  ('short_model_diesel', 0.0),
#  ('short_model_discovery', 0.0),
#  ('short_model_dts', 0.0),
#  ('short_model_dump', 0.0),
#  ('short_model_duramax', 0.0),
#  ('short_model_durangon', 0.0),
#  ('short_model_e', 0.0),
#  ('short_model_e-250', 0.0),
#  ('short_model_e-450', 0.0),
#  ('short_model_e-class', 0.0),
#  ('short_model_e-pace', 0.0),
#  ('short_model_e150', 0.0),
#  ('short_model_e250', 0.0),
#  ('short_model_e320', 0.0),
#  ('short_model_e450', 0.0),
#  ('short_model_e46', 0.0),
#  ('short_model_e500', 0.0),
#  ('short_model_echo', 0.0),
#  ('short_model_eclipse', 0.0),
#  ('short_model_econoline', 0.0),
#  ('short_model_el', 0.0),
#  ('short_model_elcamino', 0.0),
#  ('short_model_eldorado', 0.0),
#  ('short_model_element', 0.0),
#  ('short_model_enclave', 0.0),
#  ('short_model_endeavor', 0.0),
#  ('short_model_envision', 0.0),
#  ('short_model_envoy', 0.0),
#  ('short_model_eos', 0.0),
#  ('short_model_eqinox', 0.0),
#  ('short_model_es300', 0.0),
#  ('short_model_es330', 0.0),
#  ('short_model_es350', 0.0),
#  ('short_model_escape-se,', 0.0),
#  ('short_model_escort', 0.0),
#  ('short_model_evoque', 0.0),
#  ('short_model_expedition', 0.0),
#  ('short_model_f', 0.0),
#  ('short_model_f-100', 0.0),
#  ('short_model_f-350sd', 0.0),
#  ('short_model_f-450', 0.0),
#  ('short_model_f-450sd', 0.0),
#  ('short_model_f-550', 0.0),
#  ('short_model_f-650', 0.0),
#  ('short_model_f-750', 0.0),
#  ('short_model_f-pace', 0.0),
#  ('short_model_f-type', 0.0),
#  ('short_model_f1', 0.0),
#  ('short_model_f100', 0.0),
#  ('short_model_f350', 0.0),
#  ('short_model_f450', 0.0),
#  ('short_model_f450sd', 0.0),
#  ('short_model_f50', 0.0),
#  ('short_model_f550', 0.0),
#  ('short_model_f600', 0.0),
#  ('short_model_f700', 0.0),
#  ('short_model_f750', 0.0),
#  ('short_model_falcon', 0.0),
#  ('short_model_fe', 0.0),
#  ('short_model_fiero', 0.0),
#  ('short_model_firebird', 0.0),
#  ('short_model_five', 0.0),
#  ('short_model_fj40', 0.0),
#  ('short_model_fleetmaster', 0.0),
#  ('short_model_fleetwood', 0.0),
#  ('short_model_flex', 0.0),
#  ('short_model_fords', 0.0),
#  ('short_model_forester', 0.0),
#  ('short_model_forte5', 0.0),
#  ('short_model_foxbody', 0.0),
#  ('short_model_freestar', 0.0),
#  ('short_model_freightliner', 0.0),
#  ('short_model_fuso', 0.0),
#  ('short_model_fx35', 0.0),
#  ('short_model_fx45', 0.0),
#  ('short_model_g-class', 0.0),
#  ('short_model_g.', 0.0),
#  ('short_model_g20', 0.0),
#  ('short_model_g30', 0.0),
#  ('short_model_g35', 0.0),
#  ('short_model_g35x', 0.0),
#  ('short_model_g37s', 0.0),
#  ('short_model_g37x', 0.0),
#  ('short_model_g4500', 0.0),
#  ('short_model_g5', 0.0),
#  ('short_model_g8', 0.0),
#  ('short_model_galant', 0.0),
#  ('short_model_ghia', 0.0),
#  ('short_model_gl', 0.0),
#  ('short_model_gl-class', 0.0),
#  ('short_model_gl450', 0.0),
#  ('short_model_gla', 0.0),
#  ('short_model_gladiator', 0.0),
#  ('short_model_glc', 0.0),
#  ('short_model_glc-class', 0.0),
#  ('short_model_gle', 0.0),
#  ('short_model_gle-class', 0.0),
#  ('short_model_glk', 0.0),
#  ('short_model_glk-class', 0.0),
#  ('short_model_glk350', 0.0),
#  ('short_model_gls', 0.0),
#  ('short_model_gmc/chev', 0.0),
#  ('short_model_gmce', 0.0),
#  ('short_model_gmt-400', 0.0),
#  ('short_model_gr', 0.0),
#  ('short_model_grandville', 0.0),
#  ('short_model_grumman', 0.0),
#  ('short_model_gs', 0.0),
#  ('short_model_gs350', 0.0),
#  ('short_model_gs430', 0.0),
#  ('short_model_gt', 0.0),
#  ('short_model_gt-r', 0.0),
#  ('short_model_gti', 0.0),
#  ('short_model_gx460', 0.0),
#  ('short_model_gx470', 0.0),
#  ('short_model_hardbody', 0.0),
#  ('short_model_hardtop', 0.0),
#  ('short_model_hearse', 0.0),
#  ('short_model_hhr', 0.0),
#  ('short_model_hiace', 0.0),
#  ('short_model_high', 0.0),
#  ('short_model_hr-v', 0.0),
#  ('short_model_hse', 0.0),
#  ('short_model_hyndai', 0.0),
#  ('short_model_i-miev', 0.0),
#  ('short_model_i30', 0.0),
#  ('short_model_i35', 0.0),
#  ('short_model_insight', 0.0),
#  ('short_model_international', 0.0),
#  ('short_model_ion', 0.0),
#  ('short_model_ioniq', 0.0),
#  ('short_model_is250', 0.0),
#  ('short_model_is300', 0.0),
#  ('short_model_isuzu', 0.0),
#  ('short_model_jeepster', 0.0),
#  ('short_model_jimmy', 0.0),
#  ('short_model_jouney', 0.0),
#  ('short_model_journey', 0.0),
#  ('short_model_juke', 0.0),
#  ('short_model_jx35', 0.0),
#  ('short_model_k10', 0.0),
#  ('short_model_k20', 0.0),
#  ('short_model_k30', 0.0),
#  ('short_model_k5', 0.0),
#  ('short_model_kicks', 0.0),
#  ('short_model_kodiak', 0.0),
#  ('short_model_l', 0.0),
#  ('short_model_l300', 0.0),
#  ('short_model_lacrosse', 0.0),
#  ('short_model_lancer', 0.0),
#  ('short_model_landcruiser', 0.0),
#  ('short_model_legacy', 0.0),
#  ('short_model_legend', 0.0),
#  ('short_model_lemans', 0.0),
#  ('short_model_lesabre', 0.0),
#  ('short_model_liberty', 0.0),
#  ('short_model_lifted', 0.0),
#  ('short_model_lightning', 0.0),
#  ('short_model_limousine', 0.0),
#  ('short_model_long', 0.0),
#  ('short_model_lr2', 0.0),
#  ('short_model_lr3', 0.0),
#  ('short_model_lr4', 0.0),
#  ('short_model_ltd', 0.0),
#  ('short_model_lucerne', 0.0),
#  ('short_model_lx', 0.0),
#  ('short_model_m', 0.0),
#  ('short_model_m-class', 0.0),
#  ('short_model_m35', 0.0),
#  ('short_model_m5', 0.0),
#  ('short_model_macan', 0.0),
#  ('short_model_magnum', 0.0),
#  ('short_model_mallinia', 0.0),
#  ('short_model_marineer,premier', 0.0),
#  ('short_model_mariner', 0.0),
#  ('short_model_mark', 0.0),
#  ('short_model_maserati', 0.0),
#  ('short_model_matrix', 0.0),
#  ('short_model_maximum', 0.0),
#  ('short_model_mazda2', 0.0),
#  ('short_model_mazda5', 0.0),
#  ('short_model_mazda6', 0.0),
#  ('short_model_mazda6i', 0.0),
#  ('short_model_md-x', 0.0),
#  ('short_model_mercades', 0.0),
#  ('short_model_mercedes-amg', 0.0),
#  ('short_model_metris', 0.0),
#  ('short_model_mg', 0.0),
#  ('short_model_miata', 0.0),
#  ('short_model_milan', 0.0),
#  ('short_model_mkc', 0.0),
#  ('short_model_mks', 0.0),
#  ('short_model_mkt', 0.0),
#  ('short_model_ml', 0.0),
#  ('short_model_ml350', 0.0),
#  ('short_model_ml500', 0.0),
#  ('short_model_model', 0.0),
#  ('short_model_monte', 0.0),
#  ('short_model_montero', 0.0),
#  ('short_model_mountaineer', 0.0),
#  ('short_model_mpv', 0.0),
#  ('short_model_mr2', 0.0),
#  ('short_model_murano', 0.0),
#  ('short_model_mx-5', 0.0),
#  ('short_model_nautilus', 0.0),
#  ('short_model_navigator', 0.0),
#  ('short_model_neon', 0.0),
#  ('short_model_new', 0.0),
#  ('short_model_newport', 0.0),
#  ('short_model_niro', 0.0),
#  ('short_model_nitro', 0.0),
#  ('short_model_nova', 0.0),
#  ('short_model_nv1500', 0.0),
#  ('short_model_nv200', 0.0),
#  ('short_model_nv2500', 0.0),
#  ('short_model_nv2500hd', 0.0),
#  ('short_model_nx', 0.0),
#  ('short_model_nx300', 0.0),
#  ('short_model_oddyssey', 0.0),
#  ('short_model_oldsmobile', 0.0),
#  ('short_model_optima', 0.0),
#  ('short_model_optimia', 0.0),
#  ('short_model_outback', 0.0),
#  ('short_model_outlook', 0.0),
#  ('short_model_paceman', 0.0),
#  ('short_model_pacifica', 0.0),
#  ('short_model_panamera', 0.0),
#  ('short_model_panel', 0.0),
#  ('short_model_park', 0.0),
#  ('short_model_passport', 0.0),
#  ('short_model_pathfinder', 0.0),
#  ('short_model_phaeton', 0.0),
#  ('short_model_pick', 0.0),
#  ('short_model_pickup', 0.0),
#  ('short_model_pontaic', 0.0),
#  ('short_model_prelude', 0.0),
#  ('short_model_prizm', 0.0),
#  ('short_model_protege', 0.0),
#  ('short_model_pt', 0.0),
#  ('short_model_putback', 0.0),
#  ('short_model_q3', 0.0),
#  ('short_model_q5', 0.0),
#  ('short_model_q50', 0.0),
#  ('short_model_q60', 0.0),
#  ('short_model_q70', 0.0),
#  ('short_model_quattro', 0.0),
#  ('short_model_quest', 0.0),
#  ('short_model_qx50', 0.0),
#  ('short_model_qx56', 0.0),
#  ('short_model_qx60', 0.0),
#  ('short_model_qx70', 0.0),
#  ('short_model_r-class', 0.0),
#  ('short_model_r32', 0.0),
#  ('short_model_rabbit', 0.0),
#  ('short_model_rainier', 0.0),
#  ('short_model_ram1500', 0.0),
#  ('short_model_ram2500', 0.0),
#  ('short_model_ramcharger', 0.0),
#  ('short_model_range', 0.0),
#  ('short_model_ranger', 0.0),
#  ('short_model_rat', 0.0),
#  ('short_model_rav', 0.0),
#  ('short_model_rc', 0.0),
#  ('short_model_rdx', 0.0),
#  ('short_model_reatta', 0.0),
#  ('short_model_rebel', 0.0),
#  ('short_model_rendezvous', 0.0),
#  ('short_model_replica', 0.0),
#  ('short_model_ridgeline', 0.0),
#  ('short_model_rio', 0.0),
#  ('short_model_rivera', 0.0),
#  ('short_model_riviera', 0.0),
#  ('short_model_rl', 0.0),
#  ('short_model_rlx', 0.0),
#  ('short_model_roadmaster', 0.0),
#  ('short_model_roadster', 0.0),
#  ('short_model_romeo', 0.0),
#  ('short_model_rondo', 0.0),
#  ('short_model_rouge', 0.0),
#  ('short_model_routan', 0.0),
#  ('short_model_rs', 0.0),
#  ('short_model_rsx', 0.0),
#  ('short_model_rx-8', 0.0),
#  ('short_model_rx300', 0.0),
#  ('short_model_rx330', 0.0),
#  ...]

# %%
columns_mask = (clf.feature_importances_ != 0)
x_train_clear = x_train[x_train.columns[columns_mask]]
x_test_clear = x_test[x_test.columns[columns_mask]]

# %%
x_train_clear, x_test_clear, y_train, y_test = train_test_split(x, y, test_size=0.3, random_state=42)

# %%
x_train_clear.shape, x_test_clear.shape
# Out:
# ((6733, 1460), (2886, 1460))

# %%
clf = DecisionTreeClassifier()
clf.fit(x_train_clear, y_train)
# Out:
# DecisionTreeClassifier()

# %%
predicted_test = clf.predict(x_test_clear)

# %%
print(accuracy_score(y_test, predicted_test))
confusion_matrix(y_test, predicted_test)
# Out:
# 0.674982674982675
# array([[749,  48, 200],
#        [ 40, 681, 232],
#        [191, 227, 518]], dtype=int64)

# %% [markdown]
# # 1. Подготовка модели случайного леса
# Обучите простую модель классификации с помощью RandomForestClassifier. Для этого сделайте следующие шаги:
#
# # 1) На новых урезанных семплах тренировочной и тестовой выборок обучите модель случайного леса с зафиксированным random_state=50.
#
# # 2) Сделайте предикт и посчитайте точность модели и матрицу ошибок. Сравните с предыдущей моделью дерева решений. Есть ли случаи, когда модель из пункта 1 отрабатывает лучше, чем модель случайного леса?

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
x_train_clear, x_test_clear, y_train, y_test = train_test_split(x, y, test_size=0.3, random_state=50)

# %%
rf_clf = RandomForestClassifier()
rf_clf.fit(x_train_clear, y_train)
# Out:
# RandomForestClassifier()

# %%
predicted_train_rf = rf_clf.predict(x_train_clear)
predicted_test_rf = rf_clf.predict(x_test_clear)

# %%
print(accuracy_score(y_test, predicted_test_rf))
confusion_matrix(y_test, predicted_test)
# Out:
# 0.7588357588357588
# array([[305, 314, 327],
#        [328, 343, 304],
#        [347, 299, 319]], dtype=int64)

# %% [markdown]
# # Сразу бросается в глаза в первой переработанной модели FP (50) количество элементов класса 2, неверно предсказанных как 1 меньше в 6 раз чем в модели случайного леса 319/50=6.38 и FN(50) количество элементов класса 1, неверно предсказанных как 2 меньше в 6,5 раз чем в модели случайного леса 319/50=6.58.

# %% [markdown]
#  # 2. Тюнинг модели случайного леса
# Увеличьте точность модели на тестовом датасете RandomForestClassifier c помощью тюнинга параметров.
#
# Параметры, которые можно настраивать для увеличения точности:
#   `bootstrap'
#     'max_depth'
#     'max_features'
#     'min_samples_leaf'
#     'min_samples_split'
#     'random_state'
#     'n_estimators'
# Задание засчитывается, если значение метрики строго выше 0,76 на тестовом датасете.

# %%
x_train_clear, x_test_clear, y_train, y_test = train_test_split(x, y, test_size=0.3, random_state = 50)

# %%
rf_clf_2 = RandomForestClassifier(bootstrap=False, random_state = 30, n_estimators = 100, max_depth = None, max_features = 'sqrt',
                                  min_samples_leaf = 1, min_samples_split = 2)
rf_clf_2.fit(x_train_clear, y_train)
# Out:
# RandomForestClassifier(bootstrap=False, max_features='sqrt', random_state=30)

# %%
predicted_train_rf_2 = rf_clf_2.predict(x_train_clear)
predicted_test_rf_2 = rf_clf_2.predict(x_test_clear)

# %%
print(accuracy_score(y_test, predicted_test_rf_2))
confusion_matrix(y_test, predicted_test)
# Out:
# 0.7758142758142759
# array([[305, 314, 327],
#        [328, 343, 304],
#        [347, 299, 319]], dtype=int64)

# %% [markdown]
# # Перебирал разные варианты семи предложенных параметров к изменению и остановился на такой комбинации.

# %% [markdown]
# # 3. Анализ влияния фичей на модель
# Во всех задачах до вы работали над подготовленным датасетом, где фичи были заранее извлечены из текстовых переменных, отскейлены и пропущены через One Hot Encoder. Сравним, какой была бы предсказательная способность модели, если бы мы использовали только сырые данные из исходного датасета. Для этого проделайте следующие шаги:
#
# # 1) Загрузите датасет vehicles_dataset_old.csv

# %%
df_old = pd.read_csv('vehicles_dataset_old.csv')
df_old.head()
# Out:
#            id                                                url  \
# 0  7308295377  https://chattanooga.craigslist.org/ctd/d/chatt...
# 1  7316380095  https://newjersey.craigslist.org/ctd/d/carlsta...
# 2  7313733749  https://reno.craigslist.org/ctd/d/atlanta-2017...
# 3  7308210929  https://fayetteville.craigslist.org/ctd/d/rale...
# 4  7303797340  https://knoxville.craigslist.org/ctd/d/knoxvil...
#
#          region                           region_url  price  year  \
# 0   chattanooga   https://chattanooga.craigslist.org  54990  2020
# 1  north jersey     https://newjersey.craigslist.org  16942  2016
# 2  reno / tahoe          https://reno.craigslist.org  35590  2017
# 3  fayetteville  https://fayetteville.craigslist.org  14500  2013
# 4     knoxville     https://knoxville.craigslist.org  14590  2012
#
#   manufacturer                   model    fuel  odometer title_status  \
# 0          ram  2500 crew cab big horn  diesel     27442        clean
# 1         ford    explorer 4wd 4dr xlt   other     60023        clean
# 2   volkswagen        golf r hatchback     gas     14048        clean
# 3       toyota                    rav4     gas    117291        clean
# 4          bmw  1 series 128i coupe 2d   other     80465        clean
#
#   transmission                                          image_url  \
# 0        other  https://images.craigslist.org/00N0N_1xMPvfxRAI...
# 1    automatic  https://images.craigslist.org/00x0x_26jl9F0cnL...
# 2        other  https://images.craigslist.org/00y0y_eeZjWeiSfb...
# 3    automatic  https://images.craigslist.org/00606_iGe5iXidib...
# 4        other  https://images.craigslist.org/00F0F_5UAXmOzC18...
#
#                                          description state        lat  \
# 0  Carvana is the safer way to buy a car During t...    tn  35.060000
# 1  ***Call Us for more information at: 201-635-14...    nj  40.821805
# 2  Carvana is the safer way to buy a car During t...    ca  33.779214
# 3  2013 Toyota RAV4 XLE 4dr SUV     Offered by: R...    nc  35.715954
# 4  Carvana is the safer way to buy a car During t...    tn  35.970000
#
#         long              posting_date price_category  \
# 0 -85.250000  2021-04-17T12:30:50-0400           high
# 1 -74.061962  2021-05-03T15:40:21-0400         medium
# 2 -84.411811  2021-04-28T03:52:20-0700           high
# 3 -78.655304  2021-04-17T10:08:57-0400         medium
# 4 -83.940000  2021-04-08T15:10:56-0400         medium
#
#                         date
# 0  2021-04-17 16:30:50+00:00
# 1  2021-05-03 19:40:21+00:00
# 2  2021-04-28 10:52:20+00:00
# 3  2021-04-17 14:08:57+00:00
# 4  2021-04-08 19:10:56+00:00

# %% [markdown]
# # 2) Удалите из него переменную price и все строковые колонки. Дерево решений и случайный лес не умеют самостоятельно работать со строковыми значениями.

# %%
df_old_2 = df_old.copy()

# %%
y = df_old_2['price_category']

# %%
df_old_2 = df_old_2.drop(columns = ['price'])

# %%
df_old_2.shape
# Out:
# (9619, 19)

# %%
x = df_old_2.select_dtypes(exclude=['object'])
x.head()
# Out:
#            id  year  odometer        lat       long
# 0  7308295377  2020     27442  35.060000 -85.250000
# 1  7316380095  2016     60023  40.821805 -74.061962
# 2  7313733749  2017     14048  33.779214 -84.411811
# 3  7308210929  2013    117291  35.715954 -78.655304
# 4  7303797340  2012     80465  35.970000 -83.940000

# %% [markdown]
# # 3. Сформируйте x_train и x_test так же, как они были сформированы в предыдущих заданиях.

# %%
x2 = df_old_2.select_dtypes(exclude=['object'])
y2 = df_old_2['price_category']

x2_train, x2_test, y2_train, y2_test = train_test_split(x2, y2, test_size=0.3, random_state=50)

# %% [markdown]
# # 4. Обучите свою лучшую модель случайного леса на новых данных и замерьте качество. Убедитесь, что оно ухудшилось.

# %%
rf_clf_3 = RandomForestClassifier(bootstrap=False, random_state = 30, n_estimators = 100, max_depth = None, max_features = 'sqrt',
                                  min_samples_leaf = 1, min_samples_split = 2)
rf_clf_3.fit(x2_train, y2_train)
# Out:
# RandomForestClassifier(bootstrap=False, max_features='sqrt', random_state=30)

# %%
predicted_train_rf_3 = rf_clf_3.predict(x2_train)
predicted_test_rf_3 = rf_clf_3.predict(x2_test)

# %%
print(accuracy_score(y_test, predicted_test_rf_3))
confusion_matrix(y2_test, predicted_test)
# Out:
# 0.6198891198891199
# array([[305, 314, 327],
#        [328, 343, 304],
#        [347, 299, 319]], dtype=int64)

# %% [markdown]
# Да действительно ухудшилось 0.6198891198891199 < 0.7758142758142759.

# %% [markdown]
# # 5. Найдите три фичи, которые лучшим образом повлияли на предсказательную способность модели.

# %%
rf_clf_3.feature_importances_
# Out:
# array([0.16984627, 0.21927546, 0.27846047, 0.16662342, 0.16579438])

# %%
f_imp_list_new = list(zip(x2_train.columns, rf_clf_3.feature_importances_))
f_imp_list_new
# Out:
# [('id', 0.16984626752071738),
#  ('year', 0.21927546100175935),
#  ('odometer', 0.27846046686697035),
#  ('lat', 0.16662342321276888),
#  ('long', 0.16579438139778407)]

# %%
f_imp_list_new.sort(key = lambda x: x[1], reverse=True)
f_imp_list_new[0:3]
# Out:
# [('odometer', 0.27846046686697035),
#  ('year', 0.21927546100175935),
#  ('id', 0.16984626752071738)]
